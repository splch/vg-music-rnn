# %%
from glob import glob
from tqdm import tqdm
from mido import MidiFile
import string
import numpy as np
from nltk.tokenize import sent_tokenize
from itertools import tee
from numpy import array, random
from sys import getsizeof
from pickle import dump

# %%
def msg2dict(msg):
    result = dict()
    if 'note_on' in msg:
        on_ = True
    elif 'note_off' in msg:
        on_ = False
    else:
        on_ = None
    result['time'] = int(msg[msg.rfind('time'):].split(' ')[0].split('=')[1].translate(
        str.maketrans({a: None for a in string.punctuation})))
    if on_ is not None:
        for k in ['note', 'velocity']:
            result[k] = int(msg[msg.rfind(k):].split(' ')[0].split('=')[1].translate(
                str.maketrans({a: None for a in string.punctuation})))
    return [result, on_]

def switch_note(last_state, note, velocity, on_=True):
    # piano has 88 notes, corresponding to note id 21 to 108, any note out of this range will be ignored
    result = [0] * 88 if last_state is None else last_state.copy()
    if 21 <= note <= 108:
        result[note-21] = velocity if on_ else 0
    return result

def get_new_state(new_msg, last_state):
    new_msg, on_ = msg2dict(str(new_msg))
    new_state = switch_note(last_state, note=new_msg['note'], velocity=new_msg['velocity'], on_=on_) if on_ is not None else last_state
    return [new_state, new_msg['time']]

def track2seq(track):
    # piano has 88 notes, corresponding to note id 21 to 108, any note out of the id range will be ignored
    result = []
    last_state, last_time = get_new_state(str(track[0]), [0]*88)
    for i in range(1, len(track)):
        new_state, new_time = get_new_state(track[i], last_state)
        if new_time > 0:
            result += [last_state]*new_time
        last_state, last_time = new_state, new_time
    return result

# %%
def update(d, keys, value):
    for key in keys:
        if key in d:
            d = d[key]
        else:
            newd = dict()
            d[key] = newd
            d = newd
    d[value] = d.get(value, 0) + 1


def marginalize(text, window, d=dict()):
    for w in slide(text.split(' '), window):
        features = w[:-1]
        target = w[-1]
        update(d, features, target)
    return d


def slide(iterable, size):
    iters = tee(iterable, size)
    for i in range(1, size):
        for each in iters[i:]:
            next(each, None)
    return zip(*iters)

# %%
window = 2
model = dict()

pbar = tqdm(glob('midi/*.midi'))
for path in pbar:
    midi = MidiFile(path, clip=True)
    corpus = ''
    for track in midi.tracks:
        arr = np.array(track2seq(track))
        for i in range(arr.shape[0]):
            note = np.where(arr[i] > 0)
            if len(note[0]):
                corpus += str(note[0][0]) + ' '
    model = marginalize(corpus, window, model)
    pbar.set_postfix({'model (kb)': getsizeof(model)/1e3})

dump(model, open('model.pkl', 'wb'))
# Out:
#   9%|▉         | 2619/29664 [5:08:06<53:01:41,  7.06s/it, model (kb)=4.7]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/mido/midifiles/meta.py in decode(self, message, data)
#     392         try:
# --> 393             message.key = _key_signature_decode[(key, mode)]
#     394         except KeyError:
#
# KeyError: (-2, 255)
#
# During handling of the above exception, another exception occurred:
#
# KeySignatureError                         Traceback (most recent call last)
# <ipython-input-4-1621040dc818> in <module>
#       4 pbar = tqdm(glob('midi/*.midi'))
#       5 for path in pbar:
# ----> 6     midi = MidiFile(path, clip=True)
#       7     corpus = ''
#       8     for track in midi.tracks:
#
# /opt/anaconda3/lib/python3.8/site-packages/mido/midifiles/midifiles.py in __init__(self, filename, file, type, ticks_per_beat, charset, debug, clip, tracks)
#     322         elif self.filename is not None:
#     323             with io.open(filename, 'rb') as file:
# --> 324                 self._load(file)
#     325
#     326     def add_track(self, name=None):
#
# /opt/anaconda3/lib/python3.8/site-packages/mido/midifiles/midifiles.py in _load(self, infile)
#     357                     _dbg('Track {}:'.format(i))
#     358
# --> 359                 self.tracks.append(read_track(infile,
#     360                                               debug=self.debug,
#     361                                               clip=self.clip))
#
# /opt/anaconda3/lib/python3.8/site-packages/mido/midifiles/midifiles.py in read_track(infile, debug, clip)
#     215
#     216         if status_byte == 0xff:
# --> 217             msg = read_meta_message(infile, delta)
#     218         elif status_byte in [0xf0, 0xf7]:
#     219             # TODO: I'm not quite clear on the difference between
#
# /opt/anaconda3/lib/python3.8/site-packages/mido/midifiles/midifiles.py in read_meta_message(infile, delta)
#     170     length = read_variable_int(infile)
#     171     data = read_bytes(infile, length)
# --> 172     return build_meta_message(meta_type, data, delta)
#     173
#     174
#
# /opt/anaconda3/lib/python3.8/site-packages/mido/midifiles/meta.py in build_meta_message(meta_type, data, delta)
#     458
#     459         # This adds attributes to msg:
# --> 460         spec.decode(msg, data)
#     461
#     462         return msg
#
# /opt/anaconda3/lib/python3.8/site-packages/mido/midifiles/meta.py in decode(self, message, data)
#     399                 msg = ('Could not decode key with {} '
#     400                        'sharps and mode {}'.format(key, mode))
# --> 401             raise KeySignatureError(msg)
#     402
#     403     def encode(self, message):
#
# KeySignatureError: Could not decode key with 2 flats and mode 255

# %%
model
# Out:
# {'0': {'0': 514638,
#   '12': 461,
#   '1': 16,
#   '40': 3,
#   '3': 42,
#   '44': 1,
#   '2': 90,
#   '47': 2,
#   '6': 115,
#   '4': 90,
#   '9': 18,
#   '10': 118,
#   '5': 68,
#   '56': 1,
#   '7': 104,
#   '11': 22,
#   '13': 16,
#   '20': 8,
#   '25': 4,
#   '22': 1,
#   '23': 4,
#   '15': 15,
#   '18': 2,
#   '16': 1,
#   '48': 13,
#   '30': 4,
#   '32': 34,
#   '24': 97,
#   '36': 2,
#   '31': 4,
#   '14': 12,
#   '': 2,
#   '17': 2,
#   '77': 1,
#   '60': 3,
#   '19': 2,
#   '26': 1,
#   '8': 20,
#   '38': 2,
#   '28': 4,
#   '53': 2,
#   '39': 1,
#   '55': 1,
#   '46': 1},
#  '12': {'12': 17885099,
#   '10': 6765,
#   '7': 2240,
#   '5': 856,
#   '39': 216,
#   '49': 33,
#   '19': 3273,
#   '11': 1541,
#   '14': 4818,
#   '21': 1523,
#   '17': 4166,
#   '31': 436,
#   '30': 11,
#   '27': 222,
#   '13': 3992,
#   '15': 3644,
#   '24': 7785,
#   '16': 544,
#   '26': 78,
#   '55': 156,
#   '': 30,
#   '34': 308,
#   '22': 940,
#   '48': 160,
#   '43': 211,
#   '33': 335,
#   '8': 1014,
#   '40': 68,
#   '3': 59,
#   '18': 379,
#   '1': 14,
#   '9': 2022,
#   '20': 408,
#   '23': 301,
#   '25': 288,
#   '36': 757,
#   '29': 371,
#   '46': 69,
#   '35': 35,
#   '32': 317,
#   '6': 382,
#   '4': 32,
#   '60': 59,
#   '41': 183,
#   '50': 36,
#   '38': 60,
#   '0': 370,
#   '45': 71,
#   '44': 15,
#   '28': 304,
#   '42': 12,
#   '53': 102,
#   '2': 10,
#   '51': 42,
#   '72': 3,
#   '62': 38,
#   '47': 4,
#   '54': 2,
#   '58': 36,
#   '61': 1,
#   '52': 1,
#   '57': 16,
#   '65': 4,
#   '56': 1,
#   '63': 2,
#   '59': 4,
#   '79': 2,
#   '37': 1,
#   '67': 2,
#   '64': 2,
#   '85': 4},
#  '10': {'10': 14049623,
#   '12': 7967,
#   '': 22,
#   '7': 2209,
#   '8': 3010,
#   '15': 4999,
#   '25': 653,
#   '22': 6179,
#   '9': 1153,
#   '3': 736,
#   '13': 2449,
#   '11': 2322,
#   '23': 440,
#   '14': 3134,
#   '33': 376,
#   '16': 363,
#   '19': 347,
#   '20': 486,
#   '17': 2641,
#   '5': 1441,
#   '24': 121,
#   '18': 197,
#   '4': 76,
#   '21': 1813,
#   '48': 289,
#   '6': 348,
#   '32': 256,
#   '50': 36,
#   '29': 87,
#   '27': 184,
#   '31': 49,
#   '45': 591,
#   '46': 259,
#   '43': 22,
#   '0': 134,
#   '39': 44,
#   '41': 164,
#   '1': 12,
#   '34': 463,
#   '38': 202,
#   '44': 55,
#   '53': 38,
#   '49': 264,
#   '37': 45,
#   '36': 25,
#   '51': 17,
#   '62': 12,
#   '56': 2,
#   '58': 52,
#   '30': 127,
#   '42': 11,
#   '40': 20,
#   '2': 40,
#   '26': 86,
#   '52': 2,
#   '61': 93,
#   '72': 1,
#   '67': 1,
#   '55': 11,
#   '47': 28,
#   '60': 12,
#   '63': 23,
#   '81': 1,
#   '28': 192,
#   '57': 4,
#   '65': 7,
#   '71': 2,
#   '54': 2},
#  '7': {'7': 9618187,
#   '10': 2172,
#   '8': 1455,
#   '5': 1202,
#   '12': 2117,
#   '44': 39,
#   '25': 45,
#   '15': 959,
#   '19': 4166,
#   '20': 139,
#   '9': 1798,
#   '49': 33,
#   '11': 752,
#   '26': 96,
#   '17': 1146,
#   '14': 2148,
#   '1': 14,
#   '3': 580,
#   '41': 111,
#   '31': 390,
#   '22': 280,
#   '16': 129,
#   '27': 67,
#   '55': 61,
#   '23': 471,
#   '56': 16,
#   '59': 14,
#   '33': 172,
#   '6': 621,
#   '43': 123,
#   '18': 128,
#   '13': 260,
#   '30': 40,
#   '': 20,
#   '21': 874,
#   '53': 21,
#   '36': 120,
#   '4': 250,
#   '2': 170,
#   '38': 430,
#   '62': 10,
#   '34': 67,
#   '54': 11,
#   '29': 37,
#   '0': 75,
#   '68': 1,
#   '24': 45,
#   '40': 147,
#   '45': 25,
#   '50': 16,
#   '65': 10,
#   '39': 355,
#   '51': 47,
#   '46': 81,
#   '32': 88,
#   '60': 4,
#   '48': 91,
#   '70': 1,
#   '58': 11,
#   '28': 19,
#   '35': 1,
#   '47': 17,
#   '61': 68,
#   '63': 7,
#   '52': 7,
#   '37': 33,
#   '72': 2,
#   '75': 1,
#   '69': 3,
#   '67': 3,
#   '64': 6,
#   '42': 3},
#  '48': {'48': 32438451,
#   '47': 6894,
#   '46': 16741,
#   '44': 5996,
#   '43': 7706,
#   '19': 226,
#   '34': 342,
#   '21': 633,
#   '15': 1616,
#   '49': 7790,
#   '51': 9116,
#   '50': 16378,
#   '56': 1684,
#   '63': 113,
#   '41': 4408,
#   '60': 4039,
#   '45': 5410,
#   '5': 4,
#   '62': 103,
#   '53': 6477,
#   '52': 3499,
#   '38': 780,
#   '33': 751,
#   '58': 1106,
#   '35': 93,
#   '55': 3814,
#   '54': 626,
#   '65': 82,
#   '17': 634,
#   '42': 577,
#   '36': 2707,
#   '32': 284,
#   '64': 69,
#   '24': 130,
#   '31': 339,
#   '12': 254,
#   '39': 1731,
#   '37': 218,
#   '25': 93,
#   '29': 228,
#   '27': 104,
#   '20': 160,
#   '22': 89,
#   '18': 377,
#   '57': 627,
#   '10': 218,
#   '14': 683,
#   '40': 1227,
#   '8': 27,
#   '30': 40,
#   '': 54,
#   '28': 98,
#   '69': 21,
#   '67': 54,
#   '26': 76,
#   '16': 680,
#   '23': 126,
#   '68': 9,
#   '79': 5,
#   '72': 181,
#   '59': 156,
#   '6': 3,
#   '61': 715,
#   '13': 17,
#   '11': 116,
#   '70': 35,
#   '77': 5,
#   '3': 5,
#   '0': 13,
#   '83': 1,
#   '7': 94,
#   '9': 34,
#   '66': 16,
#   '76': 3,
#   '73': 1,
#   '74': 1},
#  '47': {'47': 17108312,
#   '46': 6051,
#   '50': 4498,
#   '43': 4147,
#   '45': 6050,
#   '49': 7534,
#   '44': 4100,
#   '54': 1809,
#   '38': 565,
#   '42': 3007,
#   '48': 7267,
#   '39': 878,
#   '51': 3730,
#   '40': 1657,
#   '56': 388,
#   '62': 50,
#   '52': 3330,
#   '23': 66,
#   '21': 53,
#   '36': 202,
#   '59': 626,
#   '35': 1063,
#   '30': 111,
#   '31': 110,
#   '41': 514,
#   '15': 228,
#   '17': 85,
#   '27': 28,
#   '53': 528,
#   '': 28,
#   '58': 171,
#   '32': 43,
#   '55': 712,
#   '24': 21,
#   '20': 18,
#   '37': 344,
#   '57': 281,
#   '33': 127,
#   '28': 101,
#   '61': 71,
#   '34': 94,
#   '18': 9,
#   '16': 42,
#   '12': 10,
#   '13': 23,
#   '26': 18,
#   '60': 53,
#   '72': 3,
#   '9': 28,
#   '14': 51,
#   '64': 34,
#   '68': 11,
#   '71': 61,
#   '63': 30,
#   '11': 64,
#   '29': 66,
#   '19': 78,
#   '25': 64,
#   '8': 13,
#   '6': 7,
#   '4': 6,
#   '67': 34,
#   '66': 45,
#   '79': 7,
#   '10': 10,
#   '7': 29,
#   '73': 4,
#   '65': 2,
#   '77': 3,
#   '75': 3,
#   '22': 19,
#   '5': 3,
#   '74': 1,
#   '70': 3,
#   '69': 2,
#   '2': 1},
#  '46': {'46': 32069937,
#   '48': 18466,
#   '43': 8848,
#   '7': 93,
#   '42': 4044,
#   '44': 13163,
#   '34': 2618,
#   '41': 7932,
#   '49': 6859,
#   '54': 1137,
#   '50': 5934,
#   '51': 10103,
#   '37': 718,
#   '45': 7607,
#   '47': 5938,
#   '39': 4643,
#   '35': 175,
#   '32': 184,
#   '53': 5199,
#   '21': 117,
#   '8': 43,
#   '27': 280,
#   '36': 787,
#   '22': 154,
#   '38': 1432,
#   '20': 55,
#   '58': 2379,
#   '56': 612,
#   '52': 900,
#   '17': 191,
#   '55': 1333,
#   '26': 92,
#   '19': 174,
#   '': 56,
#   '40': 604,
#   '63': 111,
#   '57': 181,
#   '60': 237,
#   '24': 105,
#   '33': 69,
#   '18': 23,
#   '29': 169,
#   '62': 203,
#   '14': 103,
#   '10': 130,
#   '70': 139,
#   '28': 32,
#   '65': 54,
#   '61': 156,
#   '59': 44,
#   '69': 15,
#   '30': 72,
#   '23': 35,
#   '16': 26,
#   '31': 244,
#   '68': 19,
#   '12': 78,
#   '15': 316,
#   '87': 2,
#   '6': 21,
#   '13': 37,
#   '67': 10,
#   '3': 25,
#   '25': 45,
#   '66': 13,
#   '75': 7,
#   '81': 1,
#   '71': 1,
#   '74': 3,
#   '64': 4,
#   '5': 6,
#   '0': 2,
#   '79': 4,
#   '86': 1,
#   '72': 4,
#   '9': 24,
#   '1': 1,
#   '82': 1,
#   '80': 4},
#  '43': {'43': 29964075,
#   '41': 14023,
#   '44': 9574,
#   '48': 7459,
#   '47': 4567,
#   '40': 4243,
#   '46': 10444,
#   '51': 1534,
#   '42': 6165,
#   '50': 3480,
#   '38': 3823,
#   '45': 10059,
#   '23': 144,
#   '21': 265,
#   '17': 379,
#   '39': 7115,
#   '65': 38,
#   '53': 899,
#   '27': 328,
#   '31': 1948,
#   '58': 94,
#   '56': 102,
#   '52': 759,
#   '32': 420,
#   '34': 1325,
#   '36': 4194,
#   '24': 162,
#   '': 50,
#   '55': 1850,
#   '35': 746,
#   '49': 748,
#   '33': 1277,
#   '63': 52,
#   '29': 383,
#   '25': 230,
#   '12': 146,
#   '54': 104,
#   '4': 12,
#   '67': 75,
#   '70': 8,
#   '22': 102,
#   '37': 526,
#   '14': 408,
#   '62': 60,
#   '69': 26,
#   '60': 144,
#   '20': 40,
#   '26': 103,
#   '28': 73,
#   '59': 79,
#   '61': 156,
#   '19': 477,
#   '79': 1,
#   '15': 497,
#   '57': 126,
#   '72': 3,
#   '11': 5,
#   '71': 11,
#   '7': 129,
#   '30': 43,
#   '18': 35,
#   '16': 27,
#   '8': 20,
#   '10': 107,
#   '66': 9,
#   '5': 19,
#   '68': 2,
#   '75': 3,
#   '3': 10,
#   '64': 15,
#   '9': 15,
#   '73': 1,
#   '74': 3,
#   '13': 4,
#   '77': 2},
#  '41': {'41': 31274696,
#   '43': 16377,
#   '45': 6131,
#   '48': 4252,
#   '44': 8542,
#   '46': 8186,
#   '37': 3653,
#   '40': 5344,
#   '35': 1044,
#   '39': 11459,
#   '47': 627,
#   '42': 6701,
#   '25': 240,
#   '53': 1626,
#   '54': 108,
#   '61': 106,
#   '57': 43,
#   '51': 1069,
#   '36': 5423,
#   '38': 6195,
#   '32': 720,
#   '58': 280,
#   '59': 23,
#   '29': 1995,
#   '34': 3236,
#   '65': 184,
#   '50': 1106,
#   '56': 136,
#   '31': 521,
#   '17': 387,
#   '0': 3,
#   '10': 153,
#   '24': 142,
#   '55': 280,
#   '27': 369,
#   '20': 183,
#   '18': 80,
#   '49': 1085,
#   '52': 132,
#   '15': 441,
#   '23': 104,
#   '63': 43,
#   '60': 349,
#   '19': 290,
#   '33': 778,
#   '13': 229,
#   '30': 189,
#   '22': 394,
#   '14': 265,
#   '62': 47,
#   '69': 4,
#   '75': 1,
#   '26': 144,
#   '28': 71,
#   '67': 26,
#   '8': 18,
#   '': 43,
#   '16': 71,
#   '7': 119,
#   '6': 16,
#   '68': 22,
#   '71': 3,
#   '12': 152,
#   '21': 168,
#   '11': 50,
#   '64': 14,
#   '5': 32,
#   '70': 6,
#   '4': 6,
#   '3': 6,
#   '79': 2,
#   '1': 3,
#   '66': 11,
#   '77': 52,
#   '9': 13,
#   '72': 1,
#   '73': 1,
#   '76': 1,
#   '84': 2,
#   '74': 2},
#  '44': {'44': 27195980,
#   '41': 6881,
#   '42': 8235,
#   '35': 641,
#   '47': 5072,
#   '40': 2137,
#   '43': 9271,
#   '48': 5928,
#   '53': 1469,
#   '52': 916,
#   '39': 4970,
#   '49': 4913,
#   '46': 14564,
#   '37': 1992,
#   '45': 4382,
#   '61': 89,
#   '51': 4162,
#   '27': 185,
#   '25': 165,
#   '57': 38,
#   '50': 1039,
#   '38': 540,
#   '21': 206,
#   '32': 1529,
#   '56': 1820,
#   '19': 135,
#   '18': 9,
#   '36': 899,
#   '63': 148,
#   '55': 292,
#   '29': 243,
#   '58': 257,
#   '54': 383,
#   '20': 136,
#   '60': 196,
#   '24': 126,
#   '34': 715,
#   '15': 202,
#   '11': 20,
#   '28': 62,
#   '26': 67,
#   '67': 13,
#   '22': 103,
#   '16': 13,
#   '30': 99,
#   '65': 35,
#   '23': 44,
#   '62': 105,
#   '6': 33,
#   '': 29,
#   '33': 129,
#   '10': 63,
#   '31': 141,
#   '17': 148,
#   '13': 139,
#   '66': 89,
#   '69': 14,
#   '64': 11,
#   '71': 2,
#   '75': 3,
#   '12': 18,
#   '8': 113,
#   '14': 234,
#   '59': 120,
#   '85': 1,
#   '70': 5,
#   '72': 2,
#   '68': 232,
#   '79': 5,
#   '5': 25,
#   '9': 84,
#   '7': 47,
#   '4': 1,
#   '80': 5,
#   '0': 3,
#   '73': 1},
#  '45': {'45': 19600873,
#   '43': 8381,
#   '48': 7649,
#   '46': 7413,
#   '42': 3901,
#   '38': 1765,
#   '47': 7487,
#   '44': 4346,
#   '54': 505,
#   '62': 58,
#   '49': 2298,
#   '61': 44,
#   '41': 5808,
#   '50': 5366,
#   '52': 1564,
#   '51': 577,
#   '53': 734,
#   '40': 2373,
#   '14': 136,
#   '57': 1073,
#   '37': 657,
#   '58': 105,
#   '36': 785,
#   '39': 597,
#   '31': 201,
#   '32': 50,
#   '63': 19,
#   '33': 771,
#   '29': 144,
#   '19': 86,
#   '59': 75,
#   '16': 17,
#   '34': 218,
#   '11': 13,
#   '55': 271,
#   '28': 82,
#   '56': 95,
#   '15': 110,
#   '25': 116,
#   '7': 35,
#   '17': 138,
#   '69': 36,
#   '27': 39,
#   '21': 67,
#   '35': 339,
#   '20': 18,
#   '6': 5,
#   '22': 23,
#   '': 32,
#   '65': 7,
#   '64': 23,
#   '60': 101,
#   '26': 71,
#   '23': 30,
#   '12': 74,
#   '2': 1,
#   '75': 9,
#   '68': 24,
#   '66': 20,
#   '30': 70,
#   '9': 47,
#   '24': 35,
#   '18': 24,
#   '67': 17,
#   '10': 595,
#   '4': 7,
#   '79': 1,
#   '8': 25,
#   '72': 11,
#   '70': 9,
#   '74': 7,
#   '13': 2,
#   '73': 1,
#   '5': 3,
#   '1': 1,
#   '3': 2},
#  '8': {'8': 8910339,
#   '10': 3706,
#   '6': 1323,
#   '7': 1038,
#   '9': 1109,
#   '4': 111,
#   '17': 384,
#   '5': 1145,
#   '20': 4827,
#   '13': 1243,
#   '11': 1540,
#   '14': 324,
#   '3': 988,
#   '22': 180,
#   '24': 35,
#   '26': 31,
#   '27': 99,
#   '19': 280,
#   '21': 388,
#   '15': 2850,
#   '1': 100,
#   '23': 29,
#   '32': 292,
#   '12': 708,
#   '18': 259,
#   '28': 4,
#   '37': 19,
#   '35': 24,
#   '30': 18,
#   '44': 125,
#   '54': 3,
#   '51': 29,
#   '48': 35,
#   '46': 41,
#   '56': 19,
#   '16': 91,
#   '36': 157,
#   '39': 199,
#   '53': 11,
#   '41': 22,
#   '64': 1,
#   '25': 113,
#   '38': 13,
#   '': 8,
#   '31': 40,
#   '42': 6,
#   '34': 30,
#   '47': 12,
#   '49': 2,
#   '2': 41,
#   '29': 8,
#   '45': 27,
#   '0': 27,
#   '55': 10,
#   '58': 7,
#   '63': 44,
#   '75': 4,
#   '68': 2,
#   '62': 2,
#   '50': 13,
#   '33': 3,
#   '60': 8,
#   '57': 17,
#   '43': 8,
#   '65': 1},
#  '6': {'6': 4580083,
#   '7': 710,
#   '18': 2484,
#   '17': 471,
#   '21': 247,
#   '36': 8,
#   '16': 130,
#   '8': 2054,
#   '39': 3,
#   '9': 281,
#   '4': 612,
#   '15': 274,
#   '11': 340,
#   '13': 925,
#   '': 6,
#   '54': 98,
#   '20': 44,
#   '10': 399,
#   '27': 4,
#   '5': 393,
#   '23': 64,
#   '34': 1,
#   '30': 52,
#   '3': 683,
#   '2': 110,
#   '0': 48,
#   '12': 379,
#   '75': 1,
#   '40': 11,
#   '46': 25,
#   '37': 4,
#   '51': 7,
#   '1': 26,
#   '19': 268,
#   '31': 4,
#   '48': 7,
#   '29': 1,
#   '52': 9,
#   '26': 7,
#   '22': 20,
#   '25': 28,
#   '41': 22,
#   '60': 3,
#   '14': 353,
#   '61': 2,
#   '55': 2,
#   '47': 1,
#   '35': 3,
#   '50': 2,
#   '56': 137,
#   '28': 2,
#   '33': 81,
#   '38': 4,
#   '44': 10,
#   '64': 1,
#   '32': 2,
#   '58': 10,
#   '42': 10,
#   '70': 1,
#   '43': 1},
#  '9': {'9': 6913147,
#   '10': 2000,
#   '5': 304,
#   '7': 1725,
#   '8': 792,
#   '29': 41,
#   '31': 8,
#   '14': 1398,
#   '11': 1306,
#   '18': 309,
#   '6': 226,
#   '3': 51,
#   '21': 2931,
#   '46': 19,
#   '15': 379,
#   '53': 3,
#   '22': 76,
#   '17': 292,
#   '36': 14,
#   '16': 830,
#   '12': 2041,
#   '23': 33,
#   '20': 99,
#   '43': 7,
#   '40': 31,
#   '52': 35,
#   '13': 275,
#   '1': 5,
#   '2': 166,
#   '0': 34,
#   '26': 41,
#   '24': 32,
#   '19': 418,
#   '4': 129,
#   '32': 28,
#   '38': 23,
#   '45': 41,
#   '48': 31,
#   '57': 8,
#   '60': 5,
#   '47': 14,
#   '51': 4,
#   '25': 24,
#   '27': 70,
#   '34': 21,
#   '37': 7,
#   '33': 59,
#   '56': 1,
#   '39': 9,
#   '28': 53,
#   '79': 2,
#   '62': 2,
#   '30': 29,
#   '': 6,
#   '42': 2,
#   '69': 28,
#   '71': 10,
#   '44': 12,
#   '65': 8,
#   '66': 7,
#   '50': 1,
#   '58': 2,
#   '35': 2,
#   '67': 3,
#   '55': 1,
#   '41': 2},
#  '5': {'5': 4534967,
#   '7': 1415,
#   '9': 241,
#   '17': 3579,
#   '3': 471,
#   '8': 1504,
#   '6': 1018,
#   '11': 108,
#   '10': 1339,
#   '48': 2,
#   '42': 1,
#   '14': 99,
#   '12': 1181,
#   '38': 10,
#   '1': 41,
#   '15': 265,
#   '22': 25,
#   '23': 22,
#   '24': 41,
#   '13': 142,
#   '4': 235,
#   '2': 35,
#   '0': 70,
#   '53': 19,
#   '19': 79,
#   '29': 74,
#   '27': 9,
#   '41': 29,
#   '18': 54,
#   '45': 3,
#   '58': 10,
#   '21': 21,
#   '20': 42,
#   '25': 15,
#   '31': 9,
#   '26': 26,
#   '43': 11,
#   '34': 89,
#   '55': 6,
#   '33': 23,
#   '': 5,
#   '52': 4,
#   '46': 14,
#   '36': 24,
#   '32': 2,
#   '44': 25,
#   '56': 20,
#   '60': 5,
#   '63': 4,
#   '62': 4,
#   '50': 1,
#   '16': 28,
#   '51': 2,
#   '77': 1,
#   '35': 1,
#   '28': 2,
#   '54': 4,
#   '37': 8,
#   '30': 2},
#  '4': {'4': 2056476,
#   '7': 296,
#   '19': 87,
#   '12': 32,
#   '6': 674,
#   '5': 210,
#   '3': 206,
#   '8': 60,
#   '11': 220,
#   '16': 969,
#   '35': 1,
#   '49': 1,
#   '13': 60,
#   '14': 65,
#   '17': 89,
#   '0': 106,
#   '2': 131,
#   '1': 73,
#   '18': 15,
#   '15': 20,
#   '47': 8,
#   '9': 175,
#   '25': 1,
#   '40': 5,
#   '52': 4,
#   '43': 5,
#   '39': 7,
#   '41': 3,
#   '45': 1,
#   '20': 24,
#   '27': 13,
#   '': 5,
#   '22': 2,
#   '54': 1,
#   '28': 3,
#   '23': 12,
#   '63': 1,
#   '10': 12,
#   '48': 1,
#   '34': 1,
#   '66': 1,
#   '53': 1,
#   '33': 1},
#  '42': {'42': 18444563,
#   '44': 8737,
#   '38': 1687,
#   '35': 1535,
#   '39': 6490,
#   '46': 4326,
#   '52': 464,
#   '37': 2500,
#   '45': 4315,
#   '36': 591,
#   '40': 5320,
#   '15': 535,
#   '47': 3211,
#   '51': 590,
#   '43': 6277,
#   '34': 778,
#   '41': 6331,
#   '27': 197,
#   '54': 1313,
#   '55': 74,
#   '62': 83,
#   '56': 68,
#   '32': 637,
#   '49': 2254,
#   '29': 59,
#   '28': 103,
#   '25': 118,
#   '24': 25,
#   '19': 112,
#   '50': 580,
#   '31': 201,
#   '48': 434,
#   '65': 31,
#   '53': 105,
#   '22': 92,
#   '30': 635,
#   '6': 28,
#   '57': 33,
#   '33': 640,
#   '16': 37,
#   '14': 196,
#   '17': 71,
#   '26': 87,
#   '20': 29,
#   '18': 86,
#   '66': 30,
#   '0': 1,
#   '': 26,
#   '59': 99,
#   '58': 63,
#   '21': 139,
#   '63': 34,
#   '60': 98,
#   '23': 99,
#   '13': 44,
#   '10': 68,
#   '11': 207,
#   '61': 105,
#   '68': 3,
#   '70': 2,
#   '3': 17,
#   '67': 6,
#   '74': 1,
#   '8': 8,
#   '7': 3,
#   '12': 5,
#   '9': 33,
#   '79': 2,
#   '64': 26,
#   '71': 1,
#   '85': 3,
#   '72': 2,
#   '5': 2,
#   '75': 1,
#   '4': 3},
#  '35': {'35': 11256817,
#   '36': 3520,
#   '37': 3464,
#   '32': 1528,
#   '30': 997,
#   '33': 2050,
#   '42': 1887,
#   '34': 2290,
#   '19': 214,
#   '39': 2262,
#   '27': 553,
#   '29': 436,
#   '38': 2652,
#   '28': 1072,
#   '46': 173,
#   '16': 312,
#   '20': 94,
#   '40': 2314,
#   '12': 33,
#   '52': 63,
#   '44': 370,
#   '25': 347,
#   '21': 475,
#   '23': 1279,
#   '47': 976,
#   '24': 162,
#   '48': 140,
#   '51': 99,
#   '50': 63,
#   '49': 78,
#   '22': 135,
#   '17': 63,
#   '43': 811,
#   '31': 1362,
#   '26': 280,
#   '45': 379,
#   '41': 684,
#   '13': 46,
#   '8': 22,
#   '4': 15,
#   '66': 12,
#   '55': 54,
#   '57': 36,
#   '15': 153,
#   '18': 72,
#   '9': 3,
#   '11': 80,
#   '14': 218,
#   '54': 32,
#   '68': 4,
#   '10': 11,
#   '': 18,
#   '53': 7,
#   '60': 2,
#   '5': 2,
#   '56': 21,
#   '72': 2,
#   '67': 6,
#   '7': 12,
#   '71': 2,
#   '65': 1,
#   '59': 21,
#   '62': 22,
#   '64': 3,
#   '63': 3,
#   '82': 1,
#   '61': 34,
#   '70': 1,
#   '3': 1,
#   '6': 1},
#  '36': {'36': 25411064,
#   '37': 4591,
#   '33': 2988,
#   '31': 2984,
#   '30': 345,
#   '32': 2808,
#   '34': 8031,
#   '38': 8659,
#   '40': 2691,
#   '28': 706,
#   '6': 9,
#   '43': 4320,
#   '41': 6247,
#   '12': 593,
#   '39': 6368,
#   '48': 2455,
#   '24': 3503,
#   '17': 1279,
#   '53': 161,
#   '': 60,
#   '29': 2351,
#   '21': 693,
#   '26': 309,
#   '35': 2802,
#   '19': 1387,
#   '20': 373,
#   '51': 176,
#   '60': 191,
#   '59': 12,
#   '52': 109,
#   '42': 649,
#   '45': 643,
#   '55': 91,
#   '44': 1014,
#   '46': 689,
#   '14': 474,
#   '23': 259,
#   '56': 121,
#   '25': 483,
#   '22': 465,
#   '27': 601,
#   '13': 157,
#   '10': 60,
#   '16': 102,
#   '15': 606,
#   '70': 7,
#   '7': 147,
#   '49': 64,
#   '63': 16,
#   '47': 124,
#   '72': 12,
#   '62': 20,
#   '8': 98,
#   '11': 3,
#   '67': 23,
#   '18': 53,
#   '58': 47,
#   '54': 14,
#   '74': 1,
#   '65': 20,
#   '66': 6,
#   '50': 94,
#   '9': 11,
#   '5': 19,
#   '68': 2,
#   '57': 62,
#   '79': 1,
#   '64': 9,
#   '75': 3,
#   '3': 1,
#   '77': 2,
#   '73': 1,
#   '61': 14,
#   '81': 1,
#   '76': 1,
#   '0': 1,
#   '69': 2},
#  '37': {'37': 15148846,
#   '38': 2760,
#   '35': 3017,
#   '33': 844,
#   '39': 7797,
#   '40': 3208,
#   '32': 2255,
#   '29': 412,
#   '34': 3702,
#   '41': 3916,
#   '44': 2405,
#   '42': 2662,
#   '23': 144,
#   '57': 6,
#   '51': 204,
#   '27': 805,
#   '28': 241,
#   '54': 115,
#   '61': 77,
#   '49': 833,
#   '25': 1436,
#   '': 25,
#   '36': 4590,
#   '30': 829,
#   '22': 318,
#   '46': 650,
#   '58': 45,
#   '13': 129,
#   '19': 135,
#   '18': 118,
#   '15': 246,
#   '21': 99,
#   '10': 62,
#   '56': 88,
#   '53': 132,
#   '52': 102,
#   '48': 107,
#   '45': 785,
#   '50': 39,
#   '17': 69,
#   '20': 115,
#   '43': 465,
#   '26': 109,
#   '31': 573,
#   '14': 52,
#   '47': 310,
#   '8': 19,
#   '16': 9,
#   '68': 7,
#   '7': 57,
#   '63': 22,
#   '59': 15,
#   '11': 28,
#   '24': 127,
#   '65': 20,
#   '60': 39,
#   '4': 4,
#   '9': 12,
#   '55': 31,
#   '5': 9,
#   '6': 5,
#   '71': 4,
#   '72': 20,
#   '67': 15,
#   '73': 7,
#   '70': 4,
#   '66': 5,
#   '62': 18,
#   '3': 23,
#   '12': 6,
#   '1': 2,
#   '64': 4,
#   '85': 1},
#  '38': {'38': 20436956,
#   '36': 6545,
#   '35': 2122,
#   '31': 2134,
#   '42': 1932,
#   '32': 892,
#   '40': 5323,
#   '34': 2974,
#   '39': 7068,
#   '37': 2433,
#   '28': 322,
#   '30': 752,
#   '23': 293,
#   '55': 153,
#   '62': 152,
#   '21': 307,
#   '41': 6763,
#   '50': 1106,
#   '43': 5109,
#   '58': 61,
#   '53': 97,
#   '44': 496,
#   '46': 1268,
#   '33': 1749,
#   '48': 418,
#   '19': 1067,
#   '45': 1671,
#   '14': 855,
#   '26': 818,
#   '27': 254,
#   '': 32,
#   '24': 340,
#   '15': 1911,
#   '49': 110,
#   '51': 172,
#   '47': 465,
#   '29': 782,
#   '22': 401,
#   '9': 15,
#   '8': 35,
#   '57': 102,
#   '3': 1,
#   '7': 628,
#   '54': 77,
#   '69': 2,
#   '17': 1375,
#   '63': 30,
#   '20': 581,
#   '25': 150,
#   '12': 54,
#   '74': 2,
#   '13': 30,
#   '52': 40,
#   '10': 157,
#   '11': 29,
#   '5': 14,
#   '65': 28,
#   '60': 153,
#   '16': 49,
#   '56': 33,
#   '61': 19,
#   '68': 5,
#   '67': 17,
#   '70': 19,
#   '79': 1,
#   '59': 18,
#   '76': 2,
#   '73': 1,
#   '18': 68,
#   '64': 4,
#   '66': 5,
#   '77': 1,
#   '75': 3,
#   '72': 1},
#  '33': {'33': 15187298,
#   '35': 2649,
#   '31': 2884,
#   '30': 802,
#   '14': 1415,
#   '28': 1089,
#   '26': 1066,
#   '19': 1158,
#   '25': 1463,
#   '36': 3212,
#   '34': 2943,
#   '37': 1149,
#   '38': 1883,
#   '39': 584,
#   '22': 275,
#   '48': 927,
#   '32': 2343,
#   '23': 654,
#   '60': 300,
#   '29': 1556,
#   '21': 2557,
#   '10': 104,
#   '': 37,
#   '24': 286,
#   '15': 3194,
#   '40': 1713,
#   '57': 86,
#   '64': 8,
#   '42': 682,
#   '20': 320,
#   '43': 1183,
#   '12': 424,
#   '41': 949,
#   '27': 442,
#   '50': 65,
#   '45': 863,
#   '55': 90,
#   '9': 38,
#   '16': 111,
#   '46': 95,
#   '62': 19,
#   '7': 180,
#   '13': 60,
#   '18': 47,
#   '51': 17,
#   '44': 225,
#   '53': 63,
#   '56': 22,
#   '49': 727,
#   '17': 1511,
#   '47': 72,
#   '11': 8,
#   '54': 35,
#   '65': 9,
#   '3': 2,
#   '73': 4,
#   '66': 2,
#   '5': 31,
#   '52': 232,
#   '59': 24,
#   '61': 14,
#   '58': 16,
#   '69': 5,
#   '4': 1,
#   '8': 34,
#   '67': 3,
#   '70': 8,
#   '71': 6,
#   '63': 1,
#   '6': 128,
#   '81': 1,
#   '68': 1},
#  '31': {'31': 15707599,
#   '38': 2455,
#   '33': 3763,
#   '34': 4274,
#   '32': 4061,
#   '26': 1936,
#   '19': 2902,
#   '24': 2183,
#   '36': 3539,
#   '11': 157,
#   '12': 439,
#   '22': 467,
#   '9': 43,
#   '15': 494,
#   '49': 31,
#   '27': 1919,
#   '29': 4527,
#   '30': 1704,
#   '23': 394,
#   '28': 1073,
#   '20': 409,
#   '41': 432,
#   '43': 1723,
#   '21': 440,
#   '55': 150,
#   '40': 342,
#   '48': 204,
#   '47': 81,
#   '60': 29,
#   '17': 463,
#   '14': 784,
#   '': 48,
#   '35': 1620,
#   '18': 120,
#   '45': 84,
#   '39': 741,
#   '10': 85,
#   '37': 690,
#   '7': 401,
#   '16': 254,
#   '58': 45,
#   '69': 2,
#   '53': 28,
#   '25': 513,
#   '61': 32,
#   '46': 157,
#   '67': 123,
#   '44': 52,
#   '52': 21,
#   '63': 18,
#   '8': 70,
#   '57': 21,
#   '51': 76,
#   '6': 10,
#   '65': 3,
#   '50': 80,
#   '42': 142,
#   '54': 21,
#   '62': 113,
#   '5': 15,
#   '3': 10,
#   '13': 85,
#   '72': 1,
#   '0': 1,
#   '79': 2,
#   '59': 11,
#   '66': 1,
#   '56': 13,
#   '73': 1,
#   '2': 1,
#   '75': 7,
#   '70': 2,
#   '77': 1,
#   '74': 4},
#  '32': {'32': 16275797,
#   '34': 6336,
#   '30': 3070,
#   '35': 2494,
#   '31': 3670,
#   '37': 2761,
#   '29': 2490,
#   '23': 280,
#   '27': 2952,
#   '25': 1430,
#   '20': 2413,
#   '39': 2396,
#   '28': 632,
#   '44': 1480,
#   '36': 2673,
#   '33': 2126,
#   '22': 951,
#   '40': 387,
#   '43': 193,
#   '41': 706,
#   '13': 478,
#   '15': 1643,
#   '60': 51,
#   '24': 528,
#   '21': 456,
#   '46': 125,
#   '48': 198,
#   '50': 23,
#   '51': 191,
#   '45': 19,
#   '47': 57,
#   '16': 34,
#   '18': 241,
#   '54': 32,
#   '14': 646,
#   '49': 107,
#   '53': 84,
#   '19': 381,
#   '26': 459,
#   '38': 709,
#   '8': 164,
#   '42': 458,
#   '56': 103,
#   '': 21,
#   '52': 21,
#   '10': 68,
#   '9': 58,
#   '58': 16,
#   '6': 1,
#   '55': 20,
#   '63': 38,
#   '12': 84,
#   '17': 664,
#   '67': 5,
#   '59': 6,
#   '70': 2,
#   '7': 112,
#   '68': 7,
#   '76': 74,
#   '65': 4,
#   '72': 2,
#   '62': 9,
#   '75': 4,
#   '61': 4,
#   '11': 24,
#   '57': 4,
#   '64': 3,
#   '71': 1,
#   '5': 5,
#   '3': 2,
#   '1': 2},
#  '34': {'34': 21536504,
#   '37': 4463,
#   '38': 3092,
#   '30': 1083,
#   '32': 5220,
#   '36': 9367,
#   '19': 425,
#   '45': 124,
#   '29': 2232,
#   '31': 3470,
#   '39': 5135,
#   '41': 3043,
#   '27': 2505,
#   '35': 2832,
#   '42': 920,
#   '56': 73,
#   '33': 2947,
#   '40': 441,
#   '48': 259,
#   '22': 3272,
#   '24': 1079,
#   '43': 1133,
#   '51': 256,
#   '23': 123,
#   '17': 810,
#   '': 40,
#   '46': 2379,
#   '44': 625,
#   '28': 406,
#   '26': 498,
#   '15': 861,
#   '25': 420,
#   '11': 22,
#   '54': 12,
#   '13': 107,
#   '20': 283,
#   '14': 390,
#   '21': 378,
#   '49': 203,
#   '18': 89,
#   '58': 183,
#   '62': 9,
#   '66': 9,
#   '50': 154,
#   '68': 3,
#   '47': 30,
#   '12': 515,
#   '55': 124,
#   '52': 62,
#   '59': 12,
#   '10': 342,
#   '65': 11,
#   '63': 17,
#   '7': 89,
#   '53': 94,
#   '16': 106,
#   '61': 12,
#   '8': 27,
#   '5': 83,
#   '84': 3,
#   '67': 9,
#   '3': 6,
#   '9': 37,
#   '1': 2,
#   '57': 17,
#   '64': 4,
#   '60': 9,
#   '79': 2,
#   '69': 2,
#   '73': 1,
#   '0': 7,
#   '72': 1,
#   '76': 1,
#   '74': 2,
#   '75': 1,
#   '6': 3,
#   '71': 1},
#  '30': {'30': 10386230,
#   '32': 3844,
#   '35': 989,
#   '33': 1284,
#   '23': 1590,
#   '26': 603,
#   '27': 2132,
#   '25': 1248,
#   '37': 1101,
#   '38': 737,
#   '44': 74,
#   '34': 1324,
#   '12': 16,
#   '15': 2222,
#   '21': 1234,
#   '16': 442,
#   '': 23,
#   '29': 2783,
#   '28': 1721,
#   '24': 190,
#   '48': 63,
#   '31': 2218,
#   '60': 17,
#   '42': 830,
#   '55': 10,
#   '36': 301,
#   '18': 2229,
#   '17': 1224,
#   '19': 1514,
#   '13': 152,
#   '40': 142,
#   '14': 1474,
#   '20': 458,
#   '41': 85,
#   '8': 31,
#   '22': 835,
#   '47': 67,
#   '49': 94,
#   '11': 100,
#   '6': 34,
#   '7': 45,
#   '43': 64,
#   '46': 71,
#   '39': 467,
#   '10': 155,
#   '58': 15,
#   '54': 53,
#   '50': 11,
#   '45': 52,
#   '57': 13,
#   '52': 10,
#   '66': 5,
#   '56': 21,
#   '68': 7,
#   '61': 137,
#   '53': 24,
#   '51': 104,
#   '63': 71,
#   '62': 9,
#   '5': 16,
#   '0': 38,
#   '78': 1,
#   '59': 12,
#   '65': 8,
#   '76': 6,
#   '75': 1,
#   '9': 4,
#   '67': 9,
#   '74': 2,
#   '3': 4},
#  '39': {'39': 28693710,
#   '35': 1662,
#   '19': 231,
#   '41': 14710,
#   '34': 4048,
#   '43': 6934,
#   '15': 979,
#   '36': 5473,
#   '60': 39,
#   '42': 6430,
#   '37': 6677,
#   '49': 930,
#   '40': 5263,
#   '38': 6243,
#   '46': 5512,
#   '51': 2989,
#   '32': 1945,
#   '33': 614,
#   '47': 963,
#   '44': 5731,
#   '48': 1874,
#   '31': 674,
#   '27': 2161,
#   '22': 399,
#   '29': 396,
#   '56': 153,
#   '26': 97,
#   '45': 1095,
#   '24': 272,
#   '52': 75,
#   '17': 179,
#   '28': 167,
#   '65': 37,
#   '53': 445,
#   '58': 101,
#   '61': 10,
#   '20': 380,
#   '18': 118,
#   '14': 589,
#   '30': 438,
#   '62': 114,
#   '': 64,
#   '55': 146,
#   '4': 1,
#   '63': 245,
#   '25': 139,
#   '21': 472,
#   '23': 244,
#   '7': 436,
#   '50': 197,
#   '3': 35,
#   '68': 27,
#   '12': 228,
#   '54': 194,
#   '11': 138,
#   '6': 12,
#   '8': 227,
#   '13': 46,
#   '71': 1,
#   '10': 35,
#   '74': 7,
#   '67': 34,
#   '59': 25,
#   '70': 28,
#   '69': 9,
#   '16': 86,
#   '75': 5,
#   '0': 9,
#   '1': 8,
#   '66': 109,
#   '77': 2,
#   '79': 3,
#   '57': 19,
#   '5': 14,
#   '64': 8,
#   '73': 3,
#   '9': 14,
#   '72': 2,
#   '2': 1,
#   '83': 1,
#   '87': 7},
#  '23': {'23': 16995394,
#   '21': 10689,
#   '18': 2461,
#   '24': 2795,
#   '25': 8308,
#   '20': 1962,
#   '30': 1669,
#   '22': 2872,
#   '17': 8425,
#   '': 67,
#   '15': 9160,
#   '19': 4568,
#   '14': 10817,
#   '33': 775,
#   '16': 1778,
#   '43': 124,
#   '40': 198,
#   '12': 624,
#   '35': 1639,
#   '27': 1200,
#   '28': 1781,
#   '31': 522,
#   '26': 1482,
#   '59': 58,
#   '51': 22,
#   '47': 62,
#   '39': 231,
#   '37': 116,
#   '11': 2552,
#   '10': 849,
#   '38': 283,
#   '3': 13,
#   '13': 359,
#   '7': 212,
#   '36': 280,
#   '74': 1,
#   '1': 4,
#   '8': 129,
#   '60': 78,
#   '32': 259,
#   '4': 54,
#   '9': 131,
#   '5': 36,
#   '6': 115,
#   '55': 10,
#   '41': 96,
#   '29': 291,
#   '34': 99,
#   '69': 3,
#   '48': 101,
#   '50': 15,
#   '42': 84,
#   '53': 49,
#   '49': 87,
#   '72': 4,
#   '52': 24,
#   '45': 40,
#   '57': 6,
#   '56': 51,
#   '62': 3,
#   '87': 1,
#   '54': 23,
#   '44': 12,
#   '0': 7,
#   '64': 19,
#   '71': 2,
#   '46': 22,
#   '66': 7,
#   '58': 7,
#   '63': 6,
#   '79': 3,
#   '67': 17,
#   '82': 1,
#   '73': 1,
#   '75': 2,
#   '81': 1},
#  '21': {'21': 30866496,
#   '25': 23989,
#   '24': 2305,
#   '23': 10712,
#   '19': 12659,
#   '18': 2176,
#   '49': 154,
#   '48': 578,
#   '58': 26,
#   '22': 3963,
#   '16': 1841,
#   '38': 423,
#   '6': 328,
#   '17': 14735,
#   '12': 1644,
#   '14': 22184,
#   '43': 294,
#   '15': 26355,
#   '30': 1201,
#   '26': 1780,
#   '': 124,
#   '28': 2493,
#   '29': 551,
#   '33': 2668,
#   '13': 390,
#   '20': 2439,
#   '10': 1583,
#   '32': 640,
#   '7': 826,
#   '8': 299,
#   '27': 846,
#   '3': 64,
#   '31': 518,
#   '36': 705,
#   '9': 2576,
#   '40': 209,
#   '37': 232,
#   '50': 29,
#   '56': 37,
#   '45': 68,
#   '57': 109,
#   '44': 243,
#   '54': 83,
#   '34': 375,
#   '11': 168,
#   '62': 15,
#   '53': 104,
#   '42': 252,
#   '41': 195,
#   '52': 21,
#   '46': 121,
#   '60': 72,
#   '55': 25,
#   '39': 503,
#   '64': 2,
#   '5': 39,
#   '63': 50,
#   '61': 257,
#   '47': 79,
#   '59': 104,
#   '35': 165,
#   '2': 8,
#   '1': 10,
#   '65': 12,
#   '71': 2,
#   '51': 70,
#   '66': 8,
#   '69': 2,
#   '67': 12,
#   '68': 9,
#   '72': 4,
#   '75': 6,
#   '4': 16,
#   '73': 1,
#   '79': 3,
#   '76': 6},
#  '25': {'25': 17362779,
#   '21': 20441,
#   '23': 8527,
#   '26': 1701,
#   '10': 659,
#   '7': 413,
#   '15': 7676,
#   '20': 3158,
#   '16': 550,
#   '37': 1733,
#   '17': 3427,
#   '30': 1704,
#   '27': 4553,
#   '49': 80,
#   '41': 276,
#   '28': 1482,
#   '32': 1605,
#   '51': 25,
#   '33': 1187,
#   '22': 1578,
#   '54': 14,
#   '24': 3488,
#   '13': 3937,
#   '29': 901,
#   '59': 12,
#   '34': 322,
#   '12': 434,
#   '36': 549,
#   '8': 224,
#   '19': 2774,
#   '18': 2019,
#   '14': 7537,
#   '70': 3,
#   '35': 207,
#   '': 64,
#   '44': 122,
#   '55': 47,
#   '57': 12,
#   '53': 95,
#   '60': 26,
#   '43': 126,
#   '31': 578,
#   '45': 68,
#   '38': 113,
#   '73': 3,
#   '47': 26,
#   '42': 70,
#   '11': 306,
#   '48': 93,
#   '5': 18,
#   '46': 31,
#   '39': 138,
#   '40': 124,
#   '64': 1,
#   '50': 23,
#   '58': 8,
#   '6': 103,
#   '68': 1,
#   '56': 46,
#   '63': 9,
#   '71': 1,
#   '66': 1,
#   '61': 11,
#   '1': 15,
#   '62': 6,
#   '0': 12,
#   '3': 9,
#   '69': 3,
#   '9': 80,
#   '67': 49,
#   '78': 6,
#   '52': 4},
#  '24': {'24': 18298627,
#   '21': 1469,
#   '25': 3492,
#   '19': 4669,
#   '18': 318,
#   '23': 1830,
#   '16': 391,
#   '27': 3584,
#   '22': 6355,
#   '17': 3467,
#   '29': 4306,
#   '14': 1032,
#   '31': 2673,
#   '20': 1731,
#   '36': 4011,
#   '26': 4839,
#   '45': 40,
#   '39': 293,
#   '12': 6549,
#   '13': 430,
#   '30': 187,
#   '43': 123,
#   '38': 260,
#   '8': 153,
#   '7': 208,
#   '48': 158,
#   '28': 1122,
#   '40': 111,
#   '15': 1669,
#   '10': 271,
#   '51': 72,
#   '41': 198,
#   '11': 191,
#   '53': 54,
#   '34': 610,
#   '33': 280,
#   '': 43,
#   '49': 38,
#   '37': 49,
#   '54': 20,
#   '69': 13,
#   '61': 4,
#   '55': 102,
#   '56': 19,
#   '60': 52,
#   '46': 94,
#   '32': 391,
#   '5': 137,
#   '63': 9,
#   '35': 133,
#   '2': 3,
#   '59': 4,
#   '57': 20,
#   '58': 29,
#   '68': 3,
#   '9': 68,
#   '4': 23,
#   '44': 30,
#   '50': 27,
#   '0': 99,
#   '72': 3,
#   '77': 9,
#   '47': 14,
#   '67': 12,
#   '71': 1,
#   '74': 2,
#   '52': 26,
#   '62': 33,
#   '42': 19,
#   '3': 8,
#   '65': 6,
#   '73': 1,
#   '66': 2,
#   '64': 1},
#  '18': {'18': 11655109,
#   '23': 2609,
#   '35': 97,
#   '8': 525,
#   '20': 3874,
#   '21': 2594,
#   '17': 2930,
#   '44': 52,
#   '41': 103,
#   '30': 2714,
#   '13': 1248,
#   '6': 1841,
#   '1': 4,
#   '14': 1922,
#   '19': 3315,
#   '22': 1354,
#   '11': 1176,
#   '48': 372,
#   '55': 3,
#   '12': 275,
#   '15': 3722,
#   '37': 122,
#   '25': 1932,
#   '33': 28,
#   '32': 175,
#   '52': 3,
#   '16': 3183,
#   '51': 42,
#   '4': 216,
#   '7': 153,
#   '39': 103,
#   '49': 150,
#   '46': 72,
#   '56': 13,
#   '28': 155,
#   '50': 9,
#   '24': 275,
#   '29': 80,
#   '5': 154,
#   '27': 249,
#   '9': 177,
#   '3': 70,
#   '': 32,
#   '26': 225,
#   '42': 150,
#   '54': 46,
#   '38': 47,
#   '10': 407,
#   '31': 39,
#   '43': 26,
#   '34': 62,
#   '2': 1,
#   '57': 3,
#   '45': 13,
#   '53': 17,
#   '66': 13,
#   '47': 9,
#   '58': 6,
#   '59': 37,
#   '36': 33,
#   '40': 44,
#   '60': 61,
#   '61': 14,
#   '79': 2,
#   '63': 3,
#   '76': 1,
#   '69': 2,
#   '62': 3,
#   '73': 2,
#   '64': 7,
#   '78': 1,
#   '67': 7,
#   '72': 1,
#   '65': 1},
#  '17': {'17': 40327092,
#   '15': 41746,
#   '19': 10454,
#   '4': 56,
#   '22': 4635,
#   '20': 4169,
#   '23': 8521,
#   '16': 3185,
#   '27': 887,
#   '34': 412,
#   '24': 4126,
#   '49': 487,
#   '5': 3025,
#   '7': 1067,
#   '3': 81,
#   '29': 5656,
#   '14': 24681,
#   '6': 701,
#   '21': 15302,
#   '18': 3434,
#   '33': 1421,
#   '31': 757,
#   '11': 260,
#   '36': 1346,
#   '58': 58,
#   '10': 2521,
#   '8': 693,
#   '': 257,
#   '28': 1987,
#   '63': 24,
#   '13': 1421,
#   '54': 171,
#   '12': 3870,
#   '26': 779,
#   '40': 241,
#   '53': 145,
#   '39': 262,
#   '25': 3357,
#   '37': 92,
#   '46': 134,
#   '35': 56,
#   '41': 438,
#   '44': 154,
#   '51': 94,
#   '48': 594,
#   '45': 142,
#   '42': 117,
#   '55': 88,
#   '43': 265,
#   '9': 268,
#   '56': 30,
#   '30': 902,
#   '47': 52,
#   '52': 172,
#   '38': 1313,
#   '32': 1083,
#   '65': 22,
#   '60': 86,
#   '57': 105,
#   '68': 9,
#   '61': 651,
#   '50': 50,
#   '73': 4,
#   '70': 10,
#   '71': 1,
#   '1': 31,
#   '59': 110,
#   '62': 12,
#   '64': 9,
#   '75': 5,
#   '0': 7,
#   '66': 4,
#   '69': 12,
#   '72': 8,
#   '67': 17,
#   '2': 11,
#   '81': 1},
#  '15': {'15': 49535678,
#   '19': 21927,
#   '17': 43774,
#   '22': 4842,
#   '23': 9084,
#   '25': 6847,
#   '10': 5344,
#   '7': 1077,
#   '21': 27219,
#   '18': 5749,
#   '14': 7816,
#   '8': 1926,
#   '12': 2558,
#   '53': 81,
#   '44': 116,
#   '13': 5034,
#   '11': 1260,
#   '3': 1394,
#   '1': 32,
#   '6': 307,
#   '16': 3839,
#   '47': 72,
#   '30': 2416,
#   '24': 1401,
#   '9': 404,
#   '39': 834,
#   '': 145,
#   '29': 680,
#   '26': 586,
#   '27': 8608,
#   '58': 72,
#   '32': 1438,
#   '20': 5437,
#   '35': 204,
#   '48': 1787,
#   '59': 118,
#   '34': 975,
#   '31': 478,
#   '33': 3487,
#   '4': 57,
#   '46': 259,
#   '41': 412,
#   '42': 461,
#   '45': 40,
#   '54': 253,
#   '63': 62,
#   '38': 2303,
#   '28': 1196,
#   '70': 12,
#   '5': 527,
#   '55': 87,
#   '36': 561,
#   '43': 581,
#   '49': 343,
#   '40': 140,
#   '37': 197,
#   '61': 569,
#   '2': 31,
#   '52': 24,
#   '64': 7,
#   '60': 111,
#   '68': 9,
#   '56': 41,
#   '51': 237,
#   '57': 28,
#   '62': 71,
#   '50': 29,
#   '72': 3,
#   '0': 11,
#   '74': 11,
#   '65': 23,
#   '67': 9,
#   '75': 4,
#   '79': 2,
#   '71': 1},
#  '19': {'19': 30020572,
#   '17': 7689,
#   '4': 125,
#   '32': 276,
#   '26': 2894,
#   '21': 14403,
#   '22': 4168,
#   '20': 6031,
#   '23': 4703,
#   '15': 22253,
#   '34': 472,
#   '48': 142,
#   '35': 233,
#   '12': 3907,
#   '7': 3759,
#   '8': 346,
#   '14': 17017,
#   '31': 3601,
#   '18': 2245,
#   '33': 1055,
#   '54': 25,
#   '36': 1383,
#   '28': 915,
#   '24': 4781,
#   '37': 126,
#   '44': 129,
#   '39': 266,
#   '42': 97,
#   '': 145,
#   '67': 6,
#   '13': 335,
#   '16': 1841,
#   '25': 2594,
#   '29': 486,
#   '27': 711,
#   '10': 601,
#   '6': 386,
#   '46': 143,
#   '51': 60,
#   '58': 13,
#   '53': 185,
#   '43': 502,
#   '41': 133,
#   '52': 21,
#   '38': 976,
#   '30': 1141,
#   '3': 46,
#   '9': 453,
#   '45': 90,
#   '40': 293,
#   '50': 102,
#   '11': 277,
#   '55': 84,
#   '56': 41,
#   '49': 238,
#   '60': 30,
#   '62': 54,
#   '77': 1,
#   '72': 1,
#   '5': 218,
#   '64': 67,
#   '57': 64,
#   '47': 106,
#   '66': 8,
#   '68': 8,
#   '61': 442,
#   '63': 29,
#   '2': 9,
#   '59': 23,
#   '69': 3,
#   '71': 8,
#   '65': 2,
#   '75': 2,
#   '0': 19,
#   '73': 2,
#   '70': 4,
#   '74': 8,
#   '79': 1},
#  '29': {'29': 16711903,
#   '32': 2800,
#   '34': 3226,
#   '18': 209,
#   '24': 3859,
#   '22': 2929,
#   '27': 4682,
#   '31': 5386,
#   '37': 532,
#   '30': 3402,
#   '41': 1909,
#   '12': 353,
#   '9': 20,
#   '17': 5194,
#   '19': 620,
#   '28': 2047,
#   '26': 1605,
#   '60': 47,
#   '36': 2959,
#   '21': 615,
#   '33': 1453,
#   '15': 777,
#   '10': 224,
#   '39': 611,
#   '20': 653,
#   '38': 763,
#   '45': 112,
#   '57': 32,
#   '50': 34,
#   '14': 250,
#   '42': 64,
#   '25': 825,
#   '53': 227,
#   '23': 356,
#   '55': 41,
#   '54': 12,
#   '11': 92,
#   '52': 42,
#   '16': 175,
#   '8': 21,
#   '': 36,
#   '13': 187,
#   '48': 191,
#   '35': 266,
#   '44': 130,
#   '3': 20,
#   '46': 99,
#   '51': 62,
#   '43': 143,
#   '5': 107,
#   '56': 41,
#   '7': 29,
#   '65': 36,
#   '58': 27,
#   '49': 40,
#   '40': 131,
#   '6': 11,
#   '78': 1,
#   '59': 6,
#   '62': 7,
#   '63': 42,
#   '74': 1,
#   '67': 7,
#   '66': 4,
#   '61': 16,
#   '47': 16,
#   '68': 3,
#   '73': 1,
#   '75': 8,
#   '0': 2,
#   '64': 16,
#   '77': 1,
#   '70': 2,
#   '87': 1},
#  '26': {'26': 10567955,
#   '24': 4146,
#   '23': 958,
#   '19': 2627,
#   '30': 686,
#   '27': 3668,
#   '20': 721,
#   '31': 2067,
#   '28': 2354,
#   '50': 56,
#   '34': 506,
#   '49': 7,
#   '22': 1531,
#   '11': 68,
#   '29': 2018,
#   '21': 1897,
#   '36': 262,
#   '25': 1534,
#   '38': 875,
#   '33': 1258,
#   '15': 736,
#   '14': 2435,
#   '8': 81,
#   '64': 3,
#   '51': 13,
#   '17': 746,
#   '53': 46,
#   '47': 12,
#   '32': 407,
#   '61': 1,
#   '35': 194,
#   '43': 81,
#   '48': 52,
#   '10': 98,
#   '16': 210,
#   '46': 44,
#   '18': 246,
#   '39': 77,
#   '42': 69,
#   '60': 8,
#   '3': 5,
#   '13': 84,
#   '': 26,
#   '62': 32,
#   '7': 234,
#   '77': 1,
#   '45': 113,
#   '40': 113,
#   '44': 51,
#   '57': 11,
#   '59': 25,
#   '41': 142,
#   '56': 2,
#   '58': 7,
#   '12': 193,
#   '37': 69,
#   '2': 6,
#   '55': 22,
#   '66': 2,
#   '9': 66,
#   '6': 7,
#   '54': 2,
#   '63': 5,
#   '52': 20,
#   '0': 1,
#   '5': 20,
#   '73': 1,
#   '67': 2,
#   '4': 1,
#   '70': 2,
#   '86': 1},
#  '20': {'20': 16234075,
#   '22': 6418,
#   '18': 2893,
#   '23': 2640,
#   '19': 5691,
#   '25': 2907,
#   '15': 6381,
#   '17': 3897,
#   '21': 2939,
#   '27': 3020,
#   '8': 4134,
#   '10': 821,
#   '32': 2881,
#   '13': 1978,
#   '24': 1501,
#   '12': 423,
#   '5': 196,
#   '7': 229,
#   '14': 1076,
#   '26': 577,
#   '31': 216,
#   '': 44,
#   '52': 1,
#   '35': 86,
#   '11': 317,
#   '30': 327,
#   '46': 42,
#   '54': 19,
#   '53': 75,
#   '16': 524,
#   '41': 224,
#   '39': 235,
#   '37': 91,
#   '48': 223,
#   '51': 37,
#   '56': 86,
#   '58': 14,
#   '29': 570,
#   '28': 354,
#   '9': 117,
#   '38': 51,
#   '36': 223,
#   '50': 12,
#   '34': 140,
#   '47': 16,
#   '44': 286,
#   '6': 170,
#   '55': 23,
#   '3': 70,
#   '33': 266,
#   '49': 22,
#   '45': 18,
#   '61': 27,
#   '40': 109,
#   '69': 7,
#   '1': 38,
#   '57': 5,
#   '42': 31,
#   '63': 12,
#   '60': 15,
#   '65': 4,
#   '43': 30,
#   '59': 5,
#   '62': 7,
#   '66': 45,
#   '0': 10,
#   '4': 16,
#   '79': 1,
#   '80': 1,
#   '78': 1,
#   '68': 56,
#   '72': 4,
#   '75': 2,
#   '67': 6,
#   '71': 1},
#  '22': {'22': 19404889,
#   '25': 2385,
#   '26': 1404,
#   '18': 844,
#   '17': 4550,
#   '15': 4889,
#   '20': 6218,
#   '10': 5465,
#   '13': 328,
#   '34': 3353,
#   '39': 327,
#   '32': 573,
#   '24': 6382,
#   '31': 576,
#   '12': 1355,
#   '21': 2753,
#   '5': 54,
#   '27': 4990,
#   '29': 3807,
#   '19': 3744,
#   '38': 490,
#   '': 40,
#   '23': 3028,
#   '62': 37,
#   '41': 181,
#   '36': 271,
#   '8': 504,
#   '14': 920,
#   '45': 31,
#   '51': 53,
#   '16': 637,
#   '54': 24,
#   '55': 42,
#   '49': 111,
#   '35': 79,
#   '56': 11,
#   '48': 59,
#   '33': 56,
#   '28': 711,
#   '40': 71,
#   '9': 544,
#   '7': 258,
#   '30': 919,
#   '75': 6,
#   '46': 179,
#   '11': 236,
#   '53': 50,
#   '37': 183,
#   '66': 6,
#   '61': 14,
#   '50': 109,
#   '44': 74,
#   '60': 16,
#   '43': 77,
#   '42': 99,
#   '47': 17,
#   '3': 287,
#   '70': 2,
#   '58': 49,
#   '57': 13,
#   '63': 13,
#   '6': 32,
#   '0': 10,
#   '2': 1,
#   '4': 4,
#   '65': 9,
#   '52': 23,
#   '73': 2,
#   '67': 1,
#   '79': 1,
#   '69': 16,
#   '1': 3,
#   '77': 3},
#  '27': {'27': 18732705,
#   '23': 956,
#   '21': 755,
#   '22': 4745,
#   '26': 3655,
#   '25': 3767,
#   '45': 39,
#   '20': 2287,
#   '16': 175,
#   '32': 2689,
#   '34': 3381,
#   '35': 477,
#   '30': 2973,
#   '29': 5836,
#   '12': 496,
#   '24': 3064,
#   '51': 189,
#   '43': 296,
#   '36': 615,
#   '31': 1733,
#   '48': 99,
#   '37': 636,
#   '13': 709,
#   '15': 7516,
#   '17': 903,
#   '28': 2000,
#   '33': 442,
#   '39': 2299,
#   '19': 841,
#   '55': 148,
#   '8': 163,
#   '10': 288,
#   '14': 345,
#   '58': 47,
#   '50': 39,
#   '11': 128,
#   '38': 157,
#   '3': 413,
#   '44': 89,
#   '46': 390,
#   '41': 179,
#   '69': 1,
#   '64': 18,
#   '18': 365,
#   '42': 131,
#   '56': 35,
#   '60': 47,
#   '53': 74,
#   '40': 44,
#   '': 35,
#   '7': 90,
#   '63': 93,
#   '5': 53,
#   '67': 5,
#   '49': 62,
#   '66': 9,
#   '47': 23,
#   '54': 46,
#   '6': 9,
#   '9': 23,
#   '62': 42,
#   '1': 42,
#   '4': 7,
#   '85': 1,
#   '61': 14,
#   '59': 3,
#   '71': 3,
#   '65': 14,
#   '68': 9,
#   '73': 3,
#   '52': 17,
#   '72': 1,
#   '84': 1,
#   '70': 2},
#  '50': {'50': 21800616,
#   '55': 4529,
#   '47': 3789,
#   '52': 7745,
#   '54': 1900,
#   '51': 11902,
#   '46': 7269,
#   '48': 13779,
#   '58': 866,
#   '53': 6545,
#   '43': 3787,
#   '44': 1183,
#   '49': 4765,
#   '28': 46,
#   '65': 89,
#   '45': 4793,
#   '62': 934,
#   '38': 1231,
#   '57': 1936,
#   '42': 413,
#   '56': 473,
#   '': 51,
#   '39': 331,
#   '41': 1215,
#   '32': 55,
#   '60': 655,
#   '59': 490,
#   '63': 39,
#   '36': 201,
#   '19': 124,
#   '20': 5,
#   '35': 85,
#   '8': 7,
#   '69': 60,
#   '26': 79,
#   '10': 65,
#   '70': 16,
#   '27': 82,
#   '61': 48,
#   '31': 119,
#   '40': 696,
#   '37': 60,
#   '64': 19,
#   '67': 35,
#   '12': 50,
#   '77': 1,
#   '15': 69,
#   '34': 150,
#   '17': 96,
#   '24': 52,
#   '66': 18,
#   '29': 41,
#   '84': 1,
#   '14': 63,
#   '30': 17,
#   '22': 73,
#   '13': 5,
#   '23': 28,
#   '7': 23,
#   '71': 5,
#   '21': 31,
#   '74': 234,
#   '33': 218,
#   '73': 1,
#   '18': 8,
#   '68': 6,
#   '9': 2,
#   '79': 12,
#   '25': 25,
#   '72': 11,
#   '87': 1,
#   '6': 2,
#   '16': 5,
#   '76': 1,
#   '80': 1,
#   '0': 1,
#   '5': 4,
#   '3': 1},
#  '55': {'55': 19600627,
#   '50': 4365,
#   '52': 3553,
#   '19': 134,
#   '51': 7301,
#   '53': 14240,
#   '49': 690,
#   '56': 8629,
#   '58': 5829,
#   '62': 1841,
#   '63': 808,
#   '48': 3265,
#   '46': 1153,
#   '57': 7145,
#   '54': 4117,
#   '42': 59,
#   '45': 632,
#   '59': 2402,
#   '47': 643,
#   '60': 4301,
#   '38': 141,
#   '43': 1913,
#   '61': 447,
#   '44': 292,
#   '37': 32,
#   '29': 67,
#   '36': 195,
#   '24': 87,
#   '39': 127,
#   '27': 109,
#   '34': 148,
#   '20': 14,
#   '12': 179,
#   '70': 74,
#   '67': 1099,
#   '64': 300,
#   '40': 77,
#   '68': 53,
#   '33': 136,
#   '31': 187,
#   '14': 271,
#   '15': 129,
#   '21': 50,
#   '17': 81,
#   '69': 86,
#   '65': 355,
#   '': 30,
#   '25': 50,
#   '22': 24,
#   '41': 378,
#   '32': 66,
#   '71': 9,
#   '16': 80,
#   '10': 8,
#   '35': 41,
#   '26': 38,
#   '75': 13,
#   '72': 48,
#   '73': 7,
#   '66': 115,
#   '79': 51,
#   '8': 8,
#   '74': 47,
#   '30': 15,
#   '13': 6,
#   '28': 29,
#   '23': 24,
#   '7': 42,
#   '5': 5,
#   '9': 2,
#   '18': 6,
#   '11': 4,
#   '80': 3,
#   '3': 2,
#   '78': 21,
#   '0': 1,
#   '84': 20,
#   '85': 10},
#  '52': {'52': 14725629,
#   '50': 6717,
#   '57': 2583,
#   '46': 717,
#   '51': 5197,
#   '56': 2032,
#   '49': 2536,
#   '54': 6021,
#   '64': 438,
#   '': 12,
#   '45': 1486,
#   '47': 2785,
#   '61': 210,
#   '53': 6335,
#   '67': 44,
#   '48': 3774,
#   '17': 321,
#   '22': 16,
#   '41': 381,
#   '43': 799,
#   '37': 86,
#   '32': 18,
#   '44': 1041,
#   '55': 4515,
#   '26': 32,
#   '38': 91,
#   '19': 31,
#   '18': 2,
#   '36': 127,
#   '40': 1115,
#   '14': 171,
#   '60': 498,
#   '39': 103,
#   '42': 421,
#   '21': 42,
#   '62': 149,
#   '33': 205,
#   '59': 1174,
#   '58': 237,
#   '23': 15,
#   '69': 13,
#   '25': 13,
#   '31': 28,
#   '63': 58,
#   '15': 54,
#   '27': 10,
#   '29': 39,
#   '72': 10,
#   '68': 15,
#   '34': 33,
#   '83': 3,
#   '76': 4,
#   '66': 56,
#   '65': 17,
#   '13': 8,
#   '11': 12,
#   '28': 53,
#   '8': 2,
#   '71': 2,
#   '30': 15,
#   '35': 60,
#   '6': 6,
#   '4': 5,
#   '24': 31,
#   '16': 30,
#   '73': 3,
#   '12': 3,
#   '70': 1,
#   '7': 9,
#   '80': 4,
#   '10': 5,
#   '75': 10,
#   '9': 37,
#   '5': 2,
#   '78': 10,
#   '82': 2,
#   '3': 2},
#  '40': {'40': 17966407,
#   '47': 1888,
#   '61': 29,
#   '41': 5871,
#   '46': 518,
#   '45': 3192,
#   '57': 448,
#   '44': 2109,
#   '43': 4916,
#   '36': 2401,
#   '38': 4339,
#   '42': 5590,
#   '39': 4964,
#   '37': 2601,
#   '51': 114,
#   '31': 503,
#   '62': 170,
#   '34': 496,
#   '32': 449,
#   '33': 1615,
#   '29': 183,
#   '35': 2050,
#   '48': 1201,
#   '28': 664,
#   '27': 57,
#   '52': 973,
#   '26': 200,
#   '10': 15,
#   '58': 21,
#   '22': 82,
#   '21': 188,
#   '50': 655,
#   '23': 371,
#   '17': 192,
#   '49': 867,
#   '8': 4,
#   '19': 271,
#   '14': 420,
#   '24': 72,
#   '69': 6,
#   '53': 212,
#   '16': 125,
#   '66': 73,
#   '67': 17,
#   '': 21,
#   '55': 56,
#   '65': 8,
#   '64': 14,
#   '7': 158,
#   '15': 269,
#   '30': 238,
#   '60': 17,
#   '9': 21,
#   '68': 5,
#   '2': 2,
#   '13': 14,
#   '11': 10,
#   '56': 58,
#   '25': 109,
#   '12': 61,
#   '18': 56,
#   '6': 15,
#   '4': 12,
#   '20': 29,
#   '54': 79,
#   '72': 1,
#   '59': 120,
#   '63': 2,
#   '75': 4,
#   '3': 1,
#   '5': 4},
#  '61': {'61': 7720100,
#   '57': 1069,
#   '59': 3122,
#   '58': 2965,
#   '63': 4267,
#   '60': 4270,
#   '53': 712,
#   '54': 737,
#   '41': 59,
#   '37': 59,
#   '56': 2825,
#   '30': 140,
#   '62': 2006,
#   '69': 82,
#   '64': 887,
#   '65': 1367,
#   '51': 368,
#   '68': 388,
#   '66': 993,
#   '48': 764,
#   '': 22,
#   '42': 130,
#   '52': 209,
#   '70': 118,
#   '55': 327,
#   '73': 220,
#   '44': 204,
#   '20': 36,
#   '40': 16,
#   '49': 915,
#   '46': 229,
#   '33': 21,
#   '50': 38,
#   '38': 60,
#   '45': 168,
#   '27': 14,
#   '43': 163,
#   '22': 46,
#   '24': 3,
#   '39': 26,
#   '13': 10,
#   '15': 179,
#   '71': 75,
#   '67': 169,
#   '31': 6,
#   '26': 3,
#   '72': 20,
#   '47': 78,
#   '34': 26,
#   '35': 55,
#   '17': 1025,
#   '12': 2,
#   '21': 187,
#   '16': 29,
#   '23': 18,
#   '19': 488,
#   '25': 10,
#   '11': 3,
#   '29': 11,
#   '14': 709,
#   '10': 116,
#   '32': 17,
#   '6': 1,
#   '9': 35,
#   '18': 10,
#   '79': 2,
#   '7': 78,
#   '75': 4,
#   '80': 3,
#   '36': 10,
#   '5': 1,
#   '77': 4,
#   '3': 4},
#  '57': {'57': 11024163,
#   '54': 2609,
#   '73': 5,
#   '58': 5585,
#   '59': 3843,
#   '50': 1765,
#   '56': 2877,
#   '52': 1903,
#   '62': 1719,
#   '49': 454,
#   '45': 1438,
#   '61': 875,
#   '40': 432,
#   '64': 576,
#   '48': 521,
#   '55': 6782,
#   '60': 3037,
#   '53': 3879,
#   '': 19,
#   '63': 134,
#   '41': 106,
#   '51': 771,
#   '43': 112,
#   '36': 48,
#   '65': 149,
#   '37': 31,
#   '35': 24,
#   '46': 304,
#   '21': 114,
#   '14': 27,
#   '69': 241,
#   '70': 24,
#   '42': 88,
#   '67': 122,
#   '47': 248,
#   '17': 131,
#   '38': 110,
#   '32': 5,
#   '68': 13,
#   '74': 4,
#   '29': 34,
#   '66': 190,
#   '44': 44,
#   '39': 22,
#   '30': 3,
#   '33': 93,
#   '26': 8,
#   '75': 8,
#   '71': 17,
#   '18': 5,
#   '15': 43,
#   '9': 10,
#   '24': 27,
#   '82': 7,
#   '20': 8,
#   '19': 60,
#   '28': 14,
#   '72': 7,
#   '25': 44,
#   '10': 3,
#   '79': 6,
#   '6': 1,
#   '34': 41,
#   '31': 25,
#   '23': 30,
#   '8': 18,
#   '16': 9,
#   '12': 18,
#   '7': 16,
#   '22': 10,
#   '80': 3,
#   '27': 4,
#   '84': 12},
#  '54': {'54': 12512147,
#   '50': 2087,
#   '57': 2751,
#   '53': 8256,
#   '52': 5459,
#   '51': 5186,
#   '49': 3637,
#   '20': 24,
#   '44': 457,
#   '56': 7368,
#   '55': 4430,
#   '70': 15,
#   '61': 989,
#   '62': 201,
#   '37': 147,
#   '27': 51,
#   '41': 118,
#   '42': 1336,
#   '38': 79,
#   '47': 1864,
#   '40': 111,
#   '39': 409,
#   '58': 2946,
#   '45': 494,
#   '48': 663,
#   '46': 769,
#   '60': 326,
#   '63': 317,
#   '15': 231,
#   '64': 221,
#   '22': 29,
#   '17': 176,
#   '29': 23,
#   '36': 38,
#   '59': 1878,
#   '35': 70,
#   '6': 100,
#   '72': 2,
#   '75': 15,
#   '33': 55,
#   '66': 606,
#   '28': 47,
#   '24': 30,
#   '23': 31,
#   '43': 181,
#   '32': 25,
#   '67': 28,
#   '65': 35,
#   '31': 34,
#   '34': 33,
#   '21': 93,
#   '19': 39,
#   '13': 15,
#   '11': 101,
#   '14': 277,
#   '16': 54,
#   '12': 2,
#   '18': 37,
#   '73': 4,
#   '69': 5,
#   '30': 39,
#   '': 17,
#   '26': 17,
#   '68': 23,
#   '9': 7,
#   '10': 4,
#   '7': 6,
#   '3': 6,
#   '8': 1,
#   '79': 1,
#   '25': 7,
#   '77': 3,
#   '80': 3,
#   '71': 13,
#   '5': 1,
#   '76': 2,
#   '78': 6},
#  '73': {'73': 873711,
#   '76': 204,
#   '70': 572,
#   '68': 805,
#   '75': 527,
#   '72': 554,
#   '71': 858,
#   '52': 1,
#   '48': 6,
#   '69': 156,
#   '74': 423,
#   '67': 24,
#   '44': 13,
#   '61': 161,
#   '62': 7,
#   '39': 3,
#   '49': 6,
#   '54': 3,
#   '22': 15,
#   '64': 41,
#   '66': 312,
#   '57': 12,
#   '65': 241,
#   '63': 161,
#   '77': 156,
#   '56': 8,
#   '51': 23,
#   '58': 45,
#   '': 3,
#   '78': 143,
#   '80': 60,
#   '11': 3,
#   '60': 18,
#   '82': 34,
#   '25': 1,
#   '27': 4,
#   '37': 8,
#   '30': 3,
#   '59': 18,
#   '85': 24,
#   '47': 1,
#   '10': 1,
#   '36': 4,
#   '87': 3,
#   '8': 1,
#   '79': 24,
#   '33': 2,
#   '45': 5,
#   '23': 2,
#   '53': 8,
#   '17': 1,
#   '19': 1,
#   '21': 1,
#   '24': 1,
#   '26': 1,
#   '29': 1,
#   '31': 1,
#   '34': 1,
#   '41': 1,
#   '43': 1,
#   '81': 20,
#   '32': 2,
#   '46': 9,
#   '18': 2,
#   '42': 6,
#   '15': 1,
#   '28': 1,
#   '83': 15,
#   '35': 1},
#  '76': {'76': 207526,
#   '47': 2,
#   '23': 2,
#   '50': 4,
#   '74': 198,
#   '64': 52,
#   '71': 179,
#   '78': 120,
#   '68': 36,
#   '75': 167,
#   '79': 265,
#   '72': 248,
#   '77': 75,
#   '81': 95,
#   '70': 16,
#   '83': 7,
#   '85': 14,
#   '62': 7,
#   '60': 2,
#   '73': 119,
#   '69': 37,
#   '32': 75,
#   '82': 5,
#   '38': 2,
#   '84': 1,
#   '58': 4,
#   '80': 24,
#   '45': 2,
#   '52': 2,
#   '87': 4,
#   '44': 1,
#   '67': 17,
#   '42': 1,
#   '16': 2,
#   '57': 3,
#   '56': 21,
#   '14': 1,
#   '18': 6,
#   '61': 9,
#   '48': 1,
#   '26': 2,
#   '66': 7,
#   '19': 6,
#   '21': 2,
#   '65': 4,
#   '53': 4,
#   '36': 3,
#   '17': 1,
#   '40': 1,
#   '41': 1,
#   '22': 1},
#  '16': {'16': 11202031,
#   '23': 2210,
#   '55': 58,
#   '15': 3589,
#   '21': 1842,
#   '12': 769,
#   '13': 1015,
#   '17': 3311,
#   '7': 186,
#   '19': 1986,
#   '18': 3545,
#   '20': 729,
#   '10': 446,
#   '53': 29,
#   '28': 1942,
#   '26': 119,
#   '44': 49,
#   '11': 1407,
#   '': 28,
#   '22': 405,
#   '25': 361,
#   '6': 213,
#   '3': 61,
#   '14': 4272,
#   '9': 810,
#   '33': 165,
#   '51': 27,
#   '43': 52,
#   '40': 285,
#   '35': 238,
#   '36': 94,
#   '48': 617,
#   '4': 756,
#   '27': 93,
#   '31': 127,
#   '5': 116,
#   '32': 48,
#   '34': 23,
#   '29': 42,
#   '24': 373,
#   '37': 9,
#   '2': 25,
#   '41': 91,
#   '64': 5,
#   '47': 37,
#   '30': 170,
#   '57': 12,
#   '49': 251,
#   '38': 156,
#   '45': 20,
#   '42': 26,
#   '54': 24,
#   '52': 33,
#   '8': 256,
#   '56': 32,
#   '61': 10,
#   '59': 124,
#   '63': 4,
#   '39': 38,
#   '46': 10,
#   '50': 4,
#   '72': 1,
#   '66': 74,
#   '67': 18,
#   '60': 18,
#   '58': 7,
#   '75': 1,
#   '76': 1,
#   '62': 1,
#   '65': 1},
#  '49': {'49': 20953732,
#   '21': 99,
#   '12': 36,
#   '51': 10285,
#   '53': 4487,
#   '46': 6226,
#   '55': 830,
#   '47': 6877,
#   '52': 3422,
#   '56': 1762,
#   '39': 1048,
#   '44': 4136,
#   '41': 931,
#   '50': 4437,
#   '48': 8030,
#   '27': 59,
#   '35': 134,
#   '54': 3550,
#   '58': 584,
#   '45': 2248,
#   '37': 879,
#   '38': 137,
#   '32': 122,
#   '8': 17,
#   '34': 183,
#   '42': 2173,
#   '26': 19,
#   '17': 487,
#   '57': 608,
#   '18': 76,
#   '20': 23,
#   '40': 911,
#   '33': 891,
#   '28': 23,
#   '7': 56,
#   '31': 35,
#   '19': 272,
#   '25': 102,
#   '36': 122,
#   '43': 753,
#   '9': 24,
#   '61': 1162,
#   '62': 52,
#   '70': 9,
#   '24': 33,
#   '60': 128,
#   '23': 154,
#   '22': 87,
#   '': 22,
#   '59': 185,
#   '65': 72,
#   '30': 80,
#   '14': 2046,
#   '10': 140,
#   '63': 146,
#   '15': 396,
#   '13': 67,
#   '16': 444,
#   '11': 31,
#   '64': 43,
#   '67': 12,
#   '76': 8,
#   '68': 21,
#   '66': 245,
#   '29': 48,
#   '79': 1,
#   '6': 3,
#   '77': 4,
#   '71': 3,
#   '74': 2,
#   '80': 1,
#   '72': 2,
#   '75': 3,
#   '1': 1,
#   '3': 2},
#  '58': {'58': 17530407,
#   '59': 3555,
#   '53': 5028,
#   '51': 2899,
#   '56': 11214,
#   '61': 3361,
#   '60': 8649,
#   '63': 3777,
#   '55': 5654,
#   '68': 132,
#   '72': 21,
#   '39': 207,
#   '57': 6752,
#   '46': 2810,
#   '62': 2305,
#   '34': 198,
#   '54': 3041,
#   '65': 1410,
#   '64': 211,
#   '44': 293,
#   '43': 185,
#   '41': 157,
#   '22': 40,
#   '38': 57,
#   '50': 953,
#   '47': 131,
#   '52': 295,
#   '': 36,
#   '29': 38,
#   '49': 477,
#   '21': 49,
#   '67': 393,
#   '48': 1005,
#   '66': 425,
#   '37': 54,
#   '40': 45,
#   '45': 71,
#   '31': 66,
#   '25': 12,
#   '27': 54,
#   '19': 17,
#   '20': 27,
#   '17': 82,
#   '42': 67,
#   '70': 898,
#   '32': 70,
#   '12': 52,
#   '69': 58,
#   '71': 49,
#   '15': 134,
#   '30': 22,
#   '35': 16,
#   '73': 52,
#   '14': 48,
#   '36': 111,
#   '10': 28,
#   '33': 10,
#   '23': 11,
#   '75': 12,
#   '79': 4,
#   '8': 8,
#   '84': 1,
#   '26': 8,
#   '13': 53,
#   '7': 13,
#   '3': 6,
#   '5': 8,
#   '28': 9,
#   '24': 26,
#   '80': 4,
#   '82': 4,
#   '11': 2,
#   '74': 4,
#   '77': 4,
#   '6': 16,
#   '78': 2,
#   '16': 2},
#  '59': {'59': 8690117,
#   '61': 3411,
#   '58': 3856,
#   '68': 159,
#   '56': 2702,
#   '54': 1751,
#   '47': 656,
#   '57': 3730,
#   '66': 734,
#   '33': 77,
#   '49': 234,
#   '': 19,
#   '60': 5001,
#   '62': 1695,
#   '55': 2654,
#   '67': 496,
#   '28': 14,
#   '25': 66,
#   '15': 92,
#   '22': 12,
#   '30': 16,
#   '32': 77,
#   '63': 1638,
#   '44': 183,
#   '64': 1414,
#   '40': 87,
#   '37': 53,
#   '51': 603,
#   '43': 109,
#   '45': 110,
#   '53': 546,
#   '48': 111,
#   '73': 45,
#   '65': 195,
#   '71': 270,
#   '52': 1300,
#   '69': 67,
#   '23': 110,
#   '16': 30,
#   '50': 380,
#   '70': 78,
#   '46': 78,
#   '19': 33,
#   '3': 4,
#   '36': 23,
#   '24': 8,
#   '42': 133,
#   '12': 3,
#   '17': 111,
#   '34': 10,
#   '41': 60,
#   '18': 31,
#   '14': 80,
#   '35': 39,
#   '39': 44,
#   '38': 42,
#   '9': 7,
#   '29': 7,
#   '20': 11,
#   '21': 113,
#   '7': 7,
#   '4': 1,
#   '13': 2,
#   '31': 15,
#   '26': 30,
#   '27': 12,
#   '80': 4,
#   '11': 8,
#   '82': 6,
#   '10': 2,
#   '85': 12,
#   '74': 3},
#  '68': {'68': 2474286,
#   '63': 1463,
#   '64': 356,
#   '66': 1610,
#   '58': 86,
#   '': 4,
#   '65': 1189,
#   '70': 1823,
#   '69': 527,
#   '61': 440,
#   '67': 1671,
#   '71': 660,
#   '54': 39,
#   '59': 142,
#   '72': 401,
#   '75': 455,
#   '73': 830,
#   '56': 790,
#   '52': 20,
#   '53': 64,
#   '57': 22,
#   '60': 182,
#   '80': 182,
#   '79': 18,
#   '37': 31,
#   '33': 6,
#   '17': 14,
#   '47': 7,
#   '62': 105,
#   '74': 84,
#   '49': 41,
#   '39': 97,
#   '35': 9,
#   '45': 7,
#   '43': 45,
# ...
#   '79': 2,
#   '5': 13,
#   '0': 1,
#   '80': 11,
#   '9': 2,
#   '86': 1,
#   '6': 2},
#  '56': {'56': 14969731,
#   '58': 10905,
#   '51': 4483,
#   '55': 9361,
#   '49': 1518,
#   '53': 6394,
#   '25': 49,
#   '80': 5,
#   '54': 7170,
#   '61': 2736,
#   '8': 24,
#   '65': 617,
#   '57': 2687,
#   '39': 213,
#   '59': 2868,
#   '62': 296,
#   '31': 24,
#   '41': 122,
#   '60': 2799,
#   '50': 499,
#   '52': 2127,
#   '44': 1544,
#   '48': 1008,
#   '36': 118,
#   '46': 748,
#   '63': 1639,
#   '47': 331,
#   '66': 200,
#   '34': 99,
#   '68': 948,
#   '37': 110,
#   '64': 229,
#   '40': 83,
#   '45': 102,
#   '13': 70,
#   '32': 107,
#   '20': 71,
#   '22': 13,
#   '18': 11,
#   '19': 41,
#   '42': 84,
#   '43': 100,
#   '16': 18,
#   '21': 113,
#   '23': 63,
#   '69': 8,
#   '30': 44,
#   '17': 108,
#   '': 21,
#   '70': 127,
#   '24': 22,
#   '7': 7,
#   '72': 29,
#   '27': 37,
#   '29': 35,
#   '38': 49,
#   '67': 115,
#   '33': 32,
#   '15': 94,
#   '10': 6,
#   '35': 30,
#   '73': 4,
#   '26': 3,
#   '14': 65,
#   '75': 5,
#   '9': 14,
#   '6': 24,
#   '79': 2,
#   '28': 8,
#   '3': 23,
#   '5': 13,
#   '11': 1,
#   '12': 2},
#  '60': {'60': 12758524,
#   '58': 9271,
#   '61': 3511,
#   '56': 3200,
#   '55': 3656,
#   '63': 3513,
#   '53': 3006,
#   '62': 6445,
#   '51': 888,
#   '50': 431,
#   '48': 3768,
#   '72': 1064,
#   '': 31,
#   '65': 2044,
#   '59': 5348,
#   '67': 1315,
#   '57': 2547,
#   '46': 197,
#   '54': 387,
#   '52': 434,
#   '77': 17,
#   '15': 139,
#   '30': 26,
#   '29': 52,
#   '18': 60,
#   '28': 19,
#   '25': 68,
#   '33': 291,
#   '40': 19,
#   '38': 54,
#   '32': 59,
#   '41': 327,
#   '22': 27,
#   '45': 103,
#   '21': 49,
#   '36': 166,
#   '64': 1311,
#   '31': 39,
#   '39': 78,
#   '44': 256,
#   '74': 9,
#   '69': 585,
#   '43': 155,
#   '79': 17,
#   '47': 55,
#   '68': 195,
#   '37': 70,
#   '17': 70,
#   '13': 12,
#   '14': 36,
#   '66': 129,
#   '42': 80,
#   '24': 52,
#   '23': 19,
#   '49': 123,
#   '12': 55,
#   '27': 39,
#   '26': 9,
#   '80': 10,
#   '82': 6,
#   '81': 2,
#   '71': 13,
#   '11': 1,
#   '75': 20,
#   '73': 4,
#   '70': 283,
#   '20': 25,
#   '34': 40,
#   '35': 4,
#   '19': 32,
#   '7': 13,
#   '10': 8,
#   '78': 1,
#   '3': 4,
#   '5': 4,
#   '76': 2,
#   '16': 31,
#   '84': 28,
#   '9': 13,
#   '4': 1},
#  '62': {'62': 7910647,
#   '60': 5788,
#   '63': 3992,
#   '55': 1806,
#   '51': 190,
#   '53': 761,
#   '32': 14,
#   '58': 2949,
#   '54': 203,
#   '59': 1878,
#   '42': 32,
#   '38': 53,
#   '61': 1975,
#   '64': 2493,
#   '69': 376,
#   '57': 1263,
#   '65': 3245,
#   '67': 1404,
#   '48': 174,
#   '43': 204,
#   '66': 428,
#   '47': 69,
#   '46': 100,
#   '50': 1116,
#   '14': 15,
#   '72': 117,
#   '71': 78,
#   '45': 46,
#   '': 25,
#   '40': 190,
#   '56': 343,
#   '30': 13,
#   '74': 303,
#   '76': 11,
#   '70': 133,
#   '68': 175,
#   '39': 177,
#   '21': 21,
#   '52': 197,
#   '31': 96,
#   '36': 56,
#   '49': 37,
#   '25': 6,
#   '19': 53,
#   '28': 5,
#   '22': 22,
#   '41': 42,
#   '44': 204,
#   '35': 18,
#   '29': 39,
#   '12': 46,
#   '15': 182,
#   '26': 39,
#   '27': 42,
#   '24': 26,
#   '33': 6,
#   '20': 4,
#   '73': 8,
#   '34': 28,
#   '37': 14,
#   '6': 1,
#   '79': 8,
#   '7': 14,
#   '9': 1,
#   '8': 2,
#   '5': 2,
#   '11': 1,
#   '17': 38,
#   '23': 4,
#   '10': 9,
#   '3': 4,
#   '0': 1,
#   '80': 3,
#   '18': 4,
#   '81': 1,
#   '16': 2,
#   '75': 5,
#   '87': 10,
#   '85': 24,
#   '78': 12},
#  '14': {'14': 31658802,
#   '12': 3368,
#   '8': 332,
#   '15': 9652,
#   '33': 1599,
#   '11': 621,
#   '16': 4779,
#   '49': 1755,
#   '23': 11097,
#   '19': 16808,
#   '18': 1819,
#   '27': 339,
#   '31': 267,
#   '25': 5852,
#   '13': 1993,
#   '17': 26940,
#   '21': 23731,
#   '35': 273,
#   '28': 1620,
#   '': 105,
#   '6': 423,
#   '5': 103,
#   '46': 39,
#   '26': 2714,
#   '30': 1633,
#   '20': 951,
#   '24': 733,
#   '10': 3291,
#   '7': 1928,
#   '29': 231,
#   '3': 86,
#   '34': 245,
#   '36': 430,
#   '9': 1648,
#   '45': 133,
#   '48': 652,
#   '22': 822,
#   '54': 249,
#   '32': 294,
#   '38': 772,
#   '51': 108,
#   '43': 326,
#   '55': 263,
#   '4': 122,
#   '39': 556,
#   '37': 22,
#   '40': 359,
#   '60': 35,
#   '41': 176,
#   '65': 25,
#   '62': 10,
#   '56': 50,
#   '44': 187,
#   '53': 24,
#   '72': 1,
#   '42': 84,
#   '47': 23,
#   '52': 296,
#   '59': 61,
#   '57': 23,
#   '58': 28,
#   '61': 802,
#   '0': 13,
#   '50': 55,
#   '2': 141,
#   '64': 17,
#   '63': 40,
#   '70': 2,
#   '68': 10,
#   '75': 5,
#   '67': 92,
#   '77': 7,
#   '76': 2,
#   '74': 1,
#   '69': 5},
#  '13': {'13': 11055044,
#   '25': 5016,
#   '15': 5711,
#   '11': 2016,
#   '10': 1997,
#   '12': 3535,
#   '1': 287,
#   '3': 222,
#   '16': 1344,
#   '20': 2330,
#   '42': 77,
#   '8': 1754,
#   '18': 1335,
#   '14': 2737,
#   '19': 296,
#   '32': 145,
#   '21': 445,
#   '36': 39,
#   '27': 345,
#   '4': 32,
#   '7': 235,
#   '33': 43,
#   '23': 570,
#   '22': 254,
#   '17': 865,
#   '9': 468,
#   '24': 109,
#   '6': 797,
#   '30': 100,
#   '41': 179,
#   '29': 111,
#   '37': 174,
#   '39': 46,
#   '58': 36,
#   '5': 187,
#   '60': 6,
#   '44': 158,
#   '62': 2,
#   '2': 13,
#   '35': 77,
#   '40': 20,
#   '34': 64,
#   '55': 7,
#   '64': 4,
#   '54': 17,
#   '52': 6,
#   '47': 31,
#   '50': 2,
#   '38': 87,
#   '49': 66,
#   '61': 10,
#   '74': 1,
#   '65': 9,
#   '56': 65,
#   '53': 47,
#   '48': 7,
#   '63': 8,
#   '51': 20,
#   '28': 60,
#   '43': 8,
#   '67': 2,
#   '0': 5,
#   '31': 54,
#   '26': 38,
#   '': 8,
#   '46': 29,
#   '45': 2,
#   '57': 1,
#   '71': 24,
#   '72': 1,
#   '59': 1},
#  '3': {'3': 4338062,
#   '15': 1699,
#   '1': 104,
#   '6': 720,
#   '8': 594,
#   '7': 377,
#   '0': 59,
#   '5': 1246,
#   '20': 106,
#   '12': 56,
#   '10': 645,
#   '4': 165,
#   '9': 55,
#   '11': 99,
#   '27': 82,
#   '23': 22,
#   '18': 247,
#   '61': 5,
#   '54': 4,
#   '51': 10,
#   '': 5,
#   '34': 6,
#   '62': 1,
#   '53': 3,
#   '17': 63,
#   '14': 26,
#   '29': 22,
#   '13': 144,
#   '41': 4,
#   '48': 3,
#   '2': 154,
#   '38': 25,
#   '22': 31,
#   '26': 5,
#   '43': 3,
#   '39': 38,
#   '16': 51,
#   '28': 4,
#   '31': 17,
#   '42': 18,
#   '25': 238,
#   '75': 1,
#   '59': 2,
#   '24': 2,
#   '19': 31,
#   '21': 6,
#   '37': 1,
#   '44': 3,
#   '60': 2,
#   '32': 6,
#   '56': 4,
#   '46': 20,
#   '45': 1,
#   '55': 2,
#   '58': 2,
#   '36': 2,
#   '57': 1,
#   '52': 2,
#   '87': 1,
#   '30': 4},
#  '72': {'72': 1395576,
#   '60': 1172,
#   '67': 692,
#   '65': 376,
#   '74': 746,
#   '70': 1292,
#   '75': 397,
#   '46': 23,
#   '56': 40,
#   '44': 16,
#   '25': 2,
#   '61': 16,
#   '68': 430,
#   '73': 391,
#   '71': 472,
#   '62': 62,
#   '77': 390,
#   '69': 316,
#   '66': 49,
#   '58': 51,
#   '53': 25,
#   '34': 5,
#   '78': 31,
#   '57': 19,
#   '45': 15,
#   '55': 102,
#   '31': 2,
#   '63': 126,
#   '38': 18,
#   '64': 47,
#   '15': 8,
#   '43': 7,
#   '': 9,
#   '41': 12,
#   '51': 29,
#   '76': 118,
#   '79': 77,
#   '59': 18,
#   '17': 5,
#   '19': 4,
#   '52': 4,
#   '24': 11,
#   '50': 1,
#   '39': 10,
#   '37': 25,
#   '36': 10,
#   '80': 28,
#   '21': 1,
#   '32': 1,
#   '12': 4,
#   '48': 117,
#   '28': 1,
#   '22': 1,
#   '47': 4,
#   '14': 5,
#   '49': 2,
#   '84': 53,
#   '83': 4,
#   '20': 5,
#   '81': 28,
#   '82': 6,
#   '29': 3,
#   '16': 1,
#   '10': 2,
#   '42': 2,
#   '5': 1,
#   '86': 6,
#   '54': 3,
#   '40': 1,
#   '35': 1},
#  '11': {'11': 8334830,
#   '10': 2071,
#   '13': 3179,
#   '14': 1341,
#   '16': 1062,
#   '17': 280,
#   '20': 116,
#   '35': 68,
#   '27': 113,
#   '12': 2450,
#   '19': 170,
#   '8': 843,
#   '9': 993,
#   '3': 165,
#   '34': 41,
#   '15': 954,
#   '21': 202,
#   '6': 398,
#   '31': 30,
#   '23': 2958,
#   '42': 206,
#   '18': 1228,
#   '7': 338,
#   '5': 112,
#   '24': 43,
#   '60': 1,
#   '25': 147,
#   '33': 2,
#   '30': 67,
#   '39': 140,
#   '22': 135,
#   '50': 4,
#   '4': 159,
#   '48': 111,
#   '': 10,
#   '66': 5,
#   '47': 80,
#   '38': 14,
#   '59': 20,
#   '54': 91,
#   '57': 2,
#   '45': 7,
#   '32': 83,
#   '41': 50,
#   '44': 31,
#   '36': 8,
#   '40': 11,
#   '51': 31,
#   '28': 59,
#   '0': 34,
#   '26': 17,
#   '52': 7,
#   '43': 5,
#   '29': 40,
#   '56': 2,
#   '1': 101,
#   '49': 25,
#   '46': 1,
#   '69': 1,
#   '70': 1,
#   '55': 5,
#   '58': 6,
#   '37': 20,
#   '63': 4,
#   '61': 2,
#   '53': 10,
#   '64': 1,
#   '2': 6},
#  '1': {'1': 539573,
#   '13': 380,
#   '15': 14,
#   '5': 39,
#   '3': 59,
#   '11': 162,
#   '2': 35,
#   '0': 108,
#   '23': 2,
#   '12': 5,
#   '6': 27,
#   '8': 110,
#   '39': 1,
#   '9': 5,
#   '10': 12,
#   '32': 1,
#   '37': 3,
#   '14': 15,
#   '': 3,
#   '17': 3,
#   '41': 6,
#   '4': 19,
#   '28': 1,
#   '21': 2,
#   '35': 1,
#   '7': 34,
#   '16': 2,
#   '25': 1,
#   '34': 2,
#   '31': 1},
#  '67': {'67': 3785134,
#   '68': 1591,
#   '62': 2413,
#   '74': 187,
#   '63': 1628,
#   '59': 374,
#   '65': 3323,
#   '55': 1125,
#   '58': 238,
#   '53': 125,
#   '45': 15,
#   '70': 1680,
#   '69': 1379,
#   '72': 779,
#   '54': 20,
#   '47': 20,
#   '60': 1072,
#   '51': 218,
#   '73': 26,
#   '35': 7,
#   '75': 86,
#   '50': 133,
#   '66': 1101,
#   '79': 140,
#   '78': 56,
#   '76': 17,
#   '64': 971,
#   '71': 290,
#   '46': 27,
#   '43': 129,
#   '36': 22,
#   '61': 76,
#   '57': 132,
#   '40': 10,
#   '24': 13,
#   '33': 3,
#   '31': 16,
#   '14': 32,
#   '48': 74,
#   '52': 13,
#   '41': 38,
#   '': 10,
#   '77': 24,
#   '15': 6,
#   '39': 41,
#   '26': 1,
#   '49': 10,
#   '27': 7,
#   '38': 16,
#   '56': 69,
#   '25': 1,
#   '37': 26,
#   '34': 19,
#   '32': 13,
#   '42': 4,
#   '44': 24,
#   '21': 112,
#   '84': 1,
#   '82': 4,
#   '16': 13,
#   '20': 1,
#   '87': 3,
#   '17': 28,
#   '9': 5,
#   '29': 8,
#   '12': 15,
#   '22': 6,
#   '23': 30,
#   '19': 16,
#   '30': 9,
#   '80': 4,
#   '11': 1,
#   '10': 1,
#   '81': 2,
#   '28': 3,
#   '7': 19,
#   '83': 12},
#  '74': {'74': 873111,
#   '77': 316,
#   '50': 11,
#   '': 7,
#   '72': 617,
#   '75': 510,
#   '71': 220,
#   '76': 148,
#   '70': 434,
#   '64': 28,
#   '67': 384,
#   '69': 435,
#   '52': 4,
#   '62': 314,
#   '73': 451,
#   '68': 37,
#   '65': 64,
#   '79': 328,
#   '82': 30,
#   '81': 27,
#   '59': 4,
#   '58': 16,
#   '60': 26,
#   '45': 5,
#   '56': 15,
#   '83': 72,
#   '78': 105,
#   '25': 1,
#   '55': 25,
#   '46': 4,
#   '43': 6,
#   '63': 28,
#   '66': 47,
#   '57': 2,
#   '23': 1,
#   '80': 27,
#   '19': 2,
#   '24': 1,
#   '8': 1,
#   '84': 5,
#   '87': 2,
#   '47': 19,
#   '48': 6,
#   '38': 9,
#   '31': 15,
#   '36': 3,
#   '17': 1,
#   '44': 6,
#   '51': 4,
#   '29': 2,
#   '85': 4,
#   '42': 2,
#   '54': 1,
#   '53': 12,
#   '14': 4,
#   '21': 5,
#   '41': 4,
#   '34': 2,
#   '37': 1,
#   '35': 1,
#   '86': 114,
#   '27': 2,
#   '32': 4,
#   '30': 7,
#   '39': 7,
#   '22': 1,
#   '7': 1},
#  '69': {'69': 1513830,
#   '71': 431,
#   '70': 1017,
#   '66': 611,
#   '67': 972,
#   '68': 555,
#   '64': 553,
#   '73': 104,
#   '61': 74,
#   '74': 416,
#   '57': 154,
#   '58': 26,
#   '81': 82,
#   '79': 26,
#   '46': 22,
#   '62': 281,
#   '60': 572,
#   '63': 357,
#   '35': 6,
#   '65': 756,
#   '75': 60,
#   '50': 37,
#   '48': 27,
#   '53': 57,
#   '45': 42,
#   '55': 97,
#   '51': 44,
#   '43': 16,
#   '41': 9,
#   '27': 2,
#   '56': 18,
#   '20': 20,
#   '24': 3,
#   '72': 393,
#   '49': 5,
#   '54': 10,
#   '85': 1,
#   '77': 40,
#   '59': 90,
#   '40': 20,
#   '30': 3,
#   '76': 42,
#   '39': 32,
#   '19': 20,
#   '': 8,
#   '47': 22,
#   '29': 5,
#   '80': 7,
#   '44': 17,
#   '37': 6,
#   '34': 1,
#   '36': 16,
#   '38': 8,
#   '52': 11,
#   '31': 4,
#   '42': 3,
#   '9': 19,
#   '14': 10,
#   '17': 4,
#   '15': 2,
#   '18': 1,
#   '33': 10,
#   '22': 18,
#   '82': 34,
#   '21': 2,
#   '7': 4,
#   '23': 2},
#  '71': {'71': 965849,
#   '75': 159,
#   '74': 257,
#   '73': 1282,
#   '70': 1573,
#   '56': 29,
#   '68': 648,
#   '72': 348,
#   '69': 456,
#   '64': 104,
#   '59': 274,
#   '62': 23,
#   '36': 7,
#   '67': 372,
#   '66': 872,
#   '60': 118,
#   '65': 27,
#   '63': 38,
#   '58': 20,
#   '78': 101,
#   '18': 10,
#   '51': 20,
#   '61': 25,
#   '52': 16,
#   '20': 1,
#   '80': 46,
#   '77': 30,
#   '34': 1,
#   '12': 1,
#   '46': 3,
#   '42': 5,
#   '54': 15,
#   '43': 2,
#   '33': 7,
#   '45': 9,
#   '': 4,
#   '49': 5,
#   '53': 7,
#   '35': 10,
#   '47': 54,
#   '38': 17,
#   '48': 10,
#   '24': 1,
#   '19': 5,
#   '39': 16,
#   '22': 3,
#   '81': 8,
#   '76': 64,
#   '44': 6,
#   '79': 18,
#   '23': 22,
#   '30': 3,
#   '50': 5,
#   '9': 6,
#   '21': 7,
#   '83': 86,
#   '57': 21,
#   '17': 2,
#   '26': 1,
#   '10': 1,
#   '14': 1,
#   '37': 5,
#   '55': 9,
#   '40': 4,
#   '28': 1},
#  '75': {'75': 858658,
#   '78': 139,
#   '74': 691,
#   '77': 439,
#   '73': 491,
#   '71': 412,
#   '68': 106,
#   '59': 10,
#   '': 5,
#   '70': 735,
#   '63': 268,
#   '72': 277,
#   '67': 181,
#   '80': 331,
#   '79': 89,
#   '31': 7,
#   '24': 4,
#   '66': 55,
#   '51': 23,
#   '65': 156,
#   '76': 148,
#   '52': 15,
#   '55': 16,
#   '82': 97,
#   '56': 9,
#   '58': 18,
#   '48': 17,
#   '60': 8,
#   '15': 7,
#   '69': 26,
#   '14': 9,
#   '44': 12,
#   '35': 3,
#   '46': 10,
#   '53': 4,
#   '34': 5,
#   '85': 26,
#   '62': 5,
#   '83': 201,
#   '84': 31,
#   '12': 1,
#   '8': 2,
#   '19': 12,
#   '17': 10,
#   '64': 17,
#   '81': 14,
#   '37': 4,
#   '41': 2,
#   '38': 6,
#   '54': 10,
#   '86': 48,
#   '32': 2,
#   '10': 1,
#   '45': 3,
#   '21': 3,
#   '11': 1,
#   '61': 7,
#   '39': 37,
#   '22': 4,
#   '23': 3,
#   '28': 5,
#   '36': 4,
#   '43': 2,
#   '49': 2,
#   '87': 32,
#   '42': 8},
#  '78': {'78': 245704,
#   '73': 211,
#   '66': 66,
#   '77': 144,
#   '79': 34,
#   '74': 114,
#   '64': 39,
#   '81': 40,
#   '75': 333,
#   '20': 2,
#   '76': 151,
#   '': 1,
#   '82': 25,
#   '83': 64,
#   '55': 32,
#   '72': 19,
#   '85': 23,
#   '67': 59,
#   '80': 255,
#   '38': 14,
#   '23': 1,
#   '71': 45,
#   '63': 35,
#   '68': 62,
#   '58': 1,
#   '69': 23,
#   '59': 6,
#   '70': 41,
#   '65': 4,
#   '9': 6,
#   '32': 1,
#   '46': 1,
#   '62': 3,
#   '14': 1,
#   '56': 3,
#   '53': 1,
#   '49': 8,
#   '19': 1,
#   '34': 1,
#   '43': 1,
#   '60': 2,
#   '15': 1},
#  '28': {'28': 10890351,
#   '35': 1213,
#   '36': 591,
#   '31': 1413,
#   '33': 1131,
#   '32': 694,
#   '11': 126,
#   '12': 464,
#   '26': 1829,
#   '29': 2189,
#   '27': 1712,
#   '17': 2226,
#   '21': 2334,
#   '19': 883,
#   '43': 58,
#   '16': 1769,
#   '38': 304,
#   '39': 87,
#   '60': 14,
#   '37': 192,
#   '18': 238,
#   '23': 1685,
#   '22': 595,
#   '24': 1049,
#   '40': 541,
#   '51': 19,
#   '30': 2103,
#   '48': 103,
#   '54': 22,
#   '57': 40,
#   '53': 19,
#   '46': 21,
#   '52': 132,
#   '49': 20,
#   '15': 1184,
#   '25': 1450,
#   '34': 397,
#   '14': 1750,
#   '': 64,
#   '20': 233,
#   '47': 194,
#   '10': 279,
#   '56': 24,
#   '44': 91,
#   '3': 5,
#   '58': 2,
#   '42': 47,
#   '70': 1,
#   '41': 39,
#   '45': 70,
#   '87': 1,
#   '62': 5,
#   '6': 8,
#   '4': 13,
#   '5': 9,
#   '9': 38,
#   '7': 22,
#   '13': 76,
#   '59': 14,
#   '64': 3,
#   '72': 1,
#   '50': 19,
#   '55': 38,
#   '8': 17,
#   '63': 9,
#   '66': 3,
#   '68': 2,
#   '75': 5,
#   '61': 4,
#   '67': 1},
#  '79': {'79': 249909,
#   '82': 54,
#   '77': 208,
#   '80': 151,
#   '67': 128,
#   '75': 289,
#   '70': 36,
#   '42': 2,
#   '56': 3,
#   '59': 2,
#   '81': 41,
#   '84': 53,
#   '38': 2,
#   '74': 443,
#   '76': 71,
#   '78': 215,
#   '72': 128,
#   '55': 92,
#   '73': 9,
#   '63': 4,
#   '36': 2,
#   '39': 1,
#   '20': 2,
#   '41': 2,
#   '45': 1,
#   '24': 2,
#   '48': 10,
#   '83': 17,
#   '68': 32,
#   '49': 1,
#   '62': 6,
#   '69': 25,
#   '40': 1,
#   '65': 2,
#   '53': 6,
#   '': 3,
#   '31': 1,
#   '21': 7,
#   '23': 2,
#   '16': 2,
#   '26': 2,
#   '71': 3,
#   '66': 2,
#   '50': 2},
#  '82': {'82': 147010,
#   '80': 134,
#   '87': 45,
#   '58': 1,
#   '77': 63,
#   '35': 2,
#   '86': 11,
#   '79': 126,
#   '70': 65,
#   '84': 58,
#   '83': 15,
#   '81': 46,
#   '67': 9,
#   '75': 42,
#   '74': 4,
#   '78': 213,
#   '76': 9,
#   '42': 5,
#   '55': 1,
#   '72': 10,
#   '60': 1,
#   '85': 17,
#   '68': 4,
#   '50': 1,
#   '63': 9,
#   '34': 3,
#   '15': 1,
#   '19': 1,
#   '26': 1,
#   '52': 1,
#   '37': 1,
#   '10': 1,
#   '62': 5,
#   '39': 1,
#   '71': 16,
#   '': 1,
#   '69': 1,
#   '61': 2,
#   '32': 1,
#   '5': 3},
#  '87': {'87': 27606,
#   '65': 1,
#   '82': 44,
#   '84': 23,
#   '35': 1,
#   '86': 46,
#   '83': 1,
#   '46': 1,
#   '85': 16,
#   '38': 1,
#   '36': 1,
#   '78': 4,
#   '32': 2,
#   '20': 1,
#   '39': 1,
#   '': 1,
#   '75': 28,
#   '74': 2,
#   '76': 2,
#   '80': 2,
#   '64': 10},
#  '83': {'83': 65303,
#   '82': 220,
#   '84': 11,
#   '47': 2,
#   '70': 13,
#   '80': 28,
#   '78': 71,
#   '75': 3,
#   '74': 2,
#   '68': 42,
#   '76': 17,
#   '79': 32,
#   '87': 3,
#   '85': 19,
#   '71': 90,
#   '38': 4,
#   '45': 2,
#   '81': 11,
#   '66': 3,
#   '63': 3,
#   '64': 1,
#   '73': 15,
#   '36': 1,
#   '59': 12},
#  '2': {'2': 444884,
#   '3': 112,
#   '4': 139,
#   '14': 207,
#   '6': 85,
#   '1': 60,
#   '7': 189,
#   '10': 57,
#   '': 3,
#   '9': 57,
#   '5': 101,
#   '62': 1,
#   '26': 4,
#   '24': 1,
#   '21': 1,
#   '12': 49,
#   '0': 62,
#   '8': 20,
#   '15': 36,
#   '58': 1,
#   '44': 1,
#   '11': 18,
#   '31': 1,
#   '23': 2,
#   '19': 9,
#   '30': 1,
#   '17': 21,
#   '13': 2,
#   '16': 2,
#   '18': 1,
#   '70': 1,
#   '55': 1},
#  '81': {'81': 68064,
#   '69': 30,
#   '79': 60,
#   '76': 172,
#   '77': 63,
#   '78': 62,
#   '82': 12,
#   '80': 36,
#   '74': 48,
#   '73': 16,
#   '75': 4,
#   '85': 10,
#   '65': 2,
#   '59': 1,
#   '72': 5,
#   '84': 6,
#   '35': 1,
#   '19': 1,
#   '38': 1,
#   '86': 4,
#   '83': 15,
#   '30': 1,
#   '50': 1,
#   '68': 4,
#   '63': 1,
#   '39': 1,
#   '26': 9,
#   '57': 12,
#   '53': 1,
#   '37': 2},
#  '86': {'86': 25979,
#   '82': 74,
#   '84': 33,
#   '80': 4,
#   '87': 22,
#   '85': 13,
#   '67': 1,
#   '48': 1,
#   '74': 109,
#   '81': 14,
#   '50': 2,
#   '31': 1,
#   '': 1,
#   '75': 4,
#   '76': 4,
#   '46': 1},
#  '84': {'84': 45008,
#   '87': 18,
#   '80': 53,
#   '70': 3,
#   '24': 1,
#   '79': 29,
#   '82': 44,
#   '72': 7,
#   '25': 1,
#   '83': 37,
#   '86': 33,
#   '85': 22,
#   '77': 9,
#   '76': 4,
#   '55': 4,
#   '81': 66,
#   '60': 71,
#   '': 2,
#   '15': 1,
#   '63': 4,
#   '34': 1,
#   '71': 3},
#  '85': {'85': 30869,
#   '84': 25,
#   '86': 6,
#   '81': 8,
#   '76': 9,
#   '75': 3,
#   '73': 20,
#   '55': 10,
#   '43': 1,
#   '34': 1,
#   '87': 16,
#   '72': 4,
#   '68': 26,
#   '83': 20,
#   '12': 1,
#   '80': 8,
#   '6': 1,
#   '78': 24,
#   '82': 6,
#   '19': 1,
#   '79': 4,
#   '51': 1,
#   '62': 46,
#   '31': 1,
#   '24': 2,
#   '': 1}}
